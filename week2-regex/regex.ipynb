# %% [markdown]
# ### Regular expressions and loops

# %% [markdown]
# Python loops
#
# Regular expressions (regex) are patterns which match parts of text. Optionally, they can also replace. They are powerful ways of finding and changing strings.
#
# The most important point is that regular expressions are not specific to Python. They're ubiquitous in programming and usually available in any piece of software that works with sequences of characters.

# %% [markdown]
# Data preparation is a large part of most DH projects. Regex is a key tool, whatever your software or programming language. Learn regex once: use everywhere!

# %% [markdown]
# Regex has limitations. We'll come back to the at the end, but regex only works with strings. In regex, the number _5_ is a string, not an integer（整数）. That means that you can find sequences of numbers but with regex alone you can't increment those numbers or do other mathematical operations on them.
#
# Fortunately a programming language can do that. So if you combine regex with something like Python you can have the best of both.

# %% [markdown]
# Let's read in _Persuasion_ again, as we did last week. First we need to get it into Colab:

# %%
# !wget https://raw.githubusercontent.com/jonathanblaney/2025-1-plain-text/refs/heads/main/persuasion.txt
# Out:
# --2025-10-20 14:57:20--  https://raw.githubusercontent.com/jonathanblaney/2025-1-plain-text/refs/heads/main/persuasion.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 497612 (486K) [text/plain]
# Saving to: ‘persuasion.txt.2’
#
# persuasion.txt.2    100%[===================>] 485.95K  --.-KB/s    in 0.03s
#
# 2025-10-20 14:57:20 (13.6 MB/s) - ‘persuasion.txt.2’ saved [497612/497612]

# %% [markdown]
# Now we can read in the text again and use the variable `persuasion` to reference it:

# %%
with open('persuasion.txt', 'r') as f:
    persuasion = f.read()

# %% [markdown]
# Last week we had a really awkward way of looking for the context in which 'Anne' occurs:

# %%
persuasion.find("Anne")
# Out:
# 2133

# %%
persuasion[2113:2153]
# Out:
# ' born\nJune 1, 1785; Anne, born August 9,'

# %% [markdown]
# To get the next occurrence we'd have to look in the slice after 2133 (note that parts of a slice can be omitted).

# %%
persuasion[2153:].find("Anne")
# Out:
# 4320

# %% [markdown]
# But...

# %%
persuasion[4300:4340]
# Out:
# 'ealed his failings, and promoted his rea'

# %% [markdown]
# We don't want to do this manually 496 times. If you want to do something repeatedly in Python a good approach is often writing a loop. Here we'll look at a *while* loop (a bit later we'll do the *for* loop).

# %% [markdown]
# Suppose you are with someone who is backing up a car towards a cliff edge. They ask you to get out and tell them when to stop. You say "keep coming" *while* there is space. When that changes you shout "Stop!" Let's write some Python for that:
#
# "f" -- x string
#
# you can break up the loop
#
# distance 越大，车走得越快
#
# 'while' loop
#
#
# 如果是前面有空格
#   print ("Stop!") -

# %%
distance = 100
while distance > 5:
    print(f"Keep coming: you've got {distance} centimeters")
    distance -= 10
    print("Stop!")
# Out:
# Keep coming: you've got 100 centimeters
# Stop!
# Keep coming: you've got 90 centimeters
# Stop!
# Keep coming: you've got 80 centimeters
# Stop!
# Keep coming: you've got 70 centimeters
# Stop!
# Keep coming: you've got 60 centimeters
# Stop!
# Keep coming: you've got 50 centimeters
# Stop!
# Keep coming: you've got 40 centimeters
# Stop!
# Keep coming: you've got 30 centimeters
# Stop!
# Keep coming: you've got 20 centimeters
# Stop!
# Keep coming: you've got 10 centimeters
# Stop!

# %%
distance = 100
while distance > 5:
    print(f"Keep coming: you've got {distance} centimeters")
    distance -= 10
print("Stop!")

# %% [markdown]
# In the same way, we could loop through the text of _Persuasion_ and look for the string we want in each fragment. Here's an approach to splitting the text in Python, using a `while` loop. But this is getting complicated immediately.

# %% [markdown]
# must start as TRUE

# %%
offset = 0
while offset < 10000:
    persuasion_chunk = persuasion[offset:offset + 100]
    print(f"chunk range currently: {offset}:{offset + 100}:\n") # show the chunk range
    print(f"{persuasion_chunk}\n")
    offset += 1000
print("finished")
# Out:
# chunk range currently: 0:100:
#
# ﻿The Project Gutenberg eBook of Persuasion
#
# This ebook is for the use of anyone anywhere in the
#
# chunk range currently: 1000:1100:
#
# I.
#  CHAPTER XIII.
#  CHAPTER XIV.
#  CHAPTER XV.
#  CHAPTER XVI.
#  CHAPTER XVII.
#  CHAPTER XVIII.
#  CHAPTER X
#
# chunk range currently: 2000:2100:
#
# Stevenson, Esq. of South Park, in the county of
# Gloucester, by which lady (who died 1800) he has iss
#
# chunk range currently: 3000:3100:
#
# Elizabeths they had married; forming altogether two
# handsome duodecimo pages, and concluding with th
#
# chunk range currently: 4000:4100:
#
# rior character to any
# thing deserved by his own. Lady Elliot had been an excellent woman,
# sensible a
#
# chunk range currently: 5000:5100:
#
# d advice, Lady Elliot mainly relied for the best help
# and maintenance of the good principles and ins
#
# chunk range currently: 6000:6100:
#
#  his eldest, he would really have given up any thing,
# which he had not been very much tempted to do.
#
# chunk range currently: 7000:7100:
#
# loom had vanished early; and as even in its height, her father had
# found little to admire in her, (s
#
# chunk range currently: 8000:8100:
#
# ht be excused, therefore, in forgetting her age, or, at least, be
# deemed only half a fool, for think
#
# chunk range currently: 9000:9100:
#
#
# seen her opening every ball of credit which a scanty neighbourhood
# afforded, and thirteen springs s
#
# finished

# %%
offset = 0
while offset < 1_0000:
    persuasion_chunk = persuasion[offset:offset + 100]
    print(f"chunk range currently: {offset}:{offset + 100}:\n") # show the chunk range
    print(f"{persuasion_chunk}\n")
    offset += 1000
print("finished")
# Out:
# chunk range currently: 0:100:
#
# ﻿The Project Gutenberg eBook of Persuasion
#
# This ebook is for the use of anyone anywhere in the
#
# chunk range currently: 1000:1100:
#
# I.
#  CHAPTER XIII.
#  CHAPTER XIV.
#  CHAPTER XV.
#  CHAPTER XVI.
#  CHAPTER XVII.
#  CHAPTER XVIII.
#  CHAPTER X
#
# chunk range currently: 2000:2100:
#
# Stevenson, Esq. of South Park, in the county of
# Gloucester, by which lady (who died 1800) he has iss
#
# chunk range currently: 3000:3100:
#
# Elizabeths they had married; forming altogether two
# handsome duodecimo pages, and concluding with th
#
# chunk range currently: 4000:4100:
#
# rior character to any
# thing deserved by his own. Lady Elliot had been an excellent woman,
# sensible a
#
# chunk range currently: 5000:5100:
#
# d advice, Lady Elliot mainly relied for the best help
# and maintenance of the good principles and ins
#
# chunk range currently: 6000:6100:
#
#  his eldest, he would really have given up any thing,
# which he had not been very much tempted to do.
#
# chunk range currently: 7000:7100:
#
# loom had vanished early; and as even in its height, her father had
# found little to admire in her, (s
#
# chunk range currently: 8000:8100:
#
# ht be excused, therefore, in forgetting her age, or, at least, be
# deemed only half a fool, for think
#
# chunk range currently: 9000:9100:
#
#
# seen her opening every ball of credit which a scanty neighbourhood
# afforded, and thirteen springs s
#
# finished

# %% [markdown]
# We're only looking for literal strings so we can't ask for the context around a string like _Anne_ because we don't know in advance what that context is. This is where _regular expressions_, also called _regex_ can help.
#
# First we need to import Python's ```re``` module. It's part of the standard library so it will be installed in any normal installation of Python.
#
# Last week we didn't import anything, which is why we were very restricted in what we could do. Most Python code you see while have imports, usually at the top of the notebook or file.

# %%
import re

# %% [markdown]
# Now we can use regex, in which some characters are _literal_ and some are _special_. Nearly every regex has a combination of both.
#
# But let's start just by running up a regex that only looks for the literal string _Anne_. Note that, because we imported the whole ```re``` library, we have to refer to ```re.findall```, not just ```findall```.
#
# We'll read the results into a variable called ```anne_context```.

# %%
anne_context = re.findall(r"Anne", persuasion)

# %% [markdown]
# The results are now held in ```anne_context```.

# %%
anne_context

# %% [markdown]
# A key special character in regex is ```.``` and it means _any character_ so we can add this either side of our literal _Anne_ string to get the context, eg 10 characters either side.
#
# literal characters
#
# & patterns

# %%
anne_context = re.findall(r"...........Anne..........", persuasion)
anne_context
# Out:
# ['e 1, 1785; Anne, born Aug',
#  'grove; but Anne, with an ',
#  'as only in Anne that she ',
#  'rs before, Anne Elliot ha',
#  'e growing. Anne haggard, ',
#  ' father of Anne and her s',
#  'ndation of Anne’s had bee',
#  'e on which Anne wanted he',
#  'untry. All Anne’s wishes ',
#  'al fate of Anne attended ',
#  'e her dear Anne’s known w',
#  'hbourhood. Anne herself w',
#  ' regard to Anne’s dislike',
#  ' What Miss Anne says, is ',
#  'place; and Anne, after th',
#  'ched, than Anne, who had ',
#  'nths ended Anne’s share o',
#  'ore, while Anne was ninet',
#  'this case, Anne had left ',
#  'ssness for Anne’s being t',
#  'g point of Anne’s conduct',
#  'ed to; but Anne, at seven',
#  'uent could Anne Elliot ha',
#  'inced that Anne would not',
#  'ished, and Anne though dr',
#  'f claiming Anne when anyt',
#  'do without Anne,” was Mar',
#  ' I am sure Anne had bette',
#  't all; and Anne, glad to ',
#  'ttled that Anne should no',
#  'ntained to Anne, in Mrs C',
#  'use, while Anne could be ',
#  ',” replied Anne, “which a',
#  'elves, and Anne walked up',
#  'ether, and Anne was set d',
#  'n; and, on Anne’s appeari',
#  ',” replied Anne. “You sen',
#  ',” replied Anne, cheerful',
#  'or me. Oh! Anne, I am so ',
#  'es abroad. Anne always co',
#  'erally, as Anne very well',
#  'same time, Anne could bel',
#  'metimes to Anne’s admirat',
#  'I am sure, Anne, if you w',
#  'alone with Anne, to say, ',
#  ' you, Miss Anne, it preve',
#  'you_, Miss Anne, because ',
#  'where; and Anne, very muc',
#  'came back. Anne had very ',
#  'od humour. Anne gave her ',
#  'a week, in Anne’s reckoni',
#  'tress, and Anne had every',
#  'ought; and Anne, in the j',
#  's, indeed, Anne. I will g',
#  'ry kind of Anne,” was her',
#  ' rushed on Anne, of which',
#  'eared, and Anne might fin',
#  'nt by you, Anne, though h',
#  'nowledge.” Anne fully sub',
#  't forgiven Anne Elliot. S',
#  ' nice; and Anne Elliot wa',
#  'tworth and Anne Elliot we',
#  ' he spoke, Anne felt the ',
#  'h reminded Anne of the ea',
#  'about me.” Anne’s shudder',
#  ' convinced Anne, that ins',
#  'tations of Anne’s slender',
#  'ind bow to Anne), “beyond',
#  ' proposed, Anne offered h',
#  'h occupied Anne, while he',
#  ' as far as Anne’s observa',
#  'ed Mary to Anne, as soon ',
#  'en seen by Anne; but she ',
#  'alone with Anne Elliot, d',
#  '” had been Anne’s reply, ',
#  'ween them. Anne longed fo',
#  'to-morrow. Anne could onl',
#  'eech. What Anne first hea',
#  ' surprised Anne if Louisa',
#  'ad married Anne instead. ',
#  'ating, and Anne distingui',
#  'e business Anne could not',
#  'ide, while Anne was never',
#  'ch as made Anne suspect t',
#  'fixed; and Anne, being en',
#  'les, Mary, Anne, Henriett',
#  'yet,” said Anne to hersel',
#  'play, that Anne felt her ',
#  'g so many. Anne had a mom',
#  'amusing to Anne; connecte',
#  'it fell to Anne’s lot to ',
#  ' was over, Anne could not',
#  'you think, Anne, it is be',
#  'ey passed, Anne’s face ca',
#  'thing like Anne Elliot ag',
#  'e inn; and Anne, in passi',
#  'le person. Anne felt that',
#  'ing roused Anne’s curiosi',
#  '! Charles, Anne, must not',
#  'n with us! Anne, must not',
#  'goes. But, Anne, only con',
#  'attention, Anne quietly t',
#  '“No,” said Anne, “that I ',
#  'enwick and Anne, who caug',
#  'im,” cried Anne, “for hea',
#  'Wentworth, Anne, or Charl',
#  'is manner, Anne walking b',
#  'Wentworth, Anne was sure ',
#  'oint, when Anne, coming q',
#  'en; but if Anne will stay',
#  'instead of Anne; Anne, wh',
#  ' useful as Anne? And to g',
#  'f Mary for Anne was inevi',
#  'ception of Anne; or must ',
#  'emotion to Anne, she quit',
#  't on fast. Anne was aston',
#  'last hill, Anne found her',
#  'mainder of Anne’s time at',
#  'ut without Anne, it would',
#  ' way, that Anne thought s',
#  'sion, that Anne was delig',
#  'with them, Anne would hav',
#  'd by both. Anne was consc',
#  'alue of an Anne Elliot, s',
#  'eir way to Anne, she coul',
#  ' her soon. Anne, have you',
#  'ch moments Anne had no po',
#  'ad brought Anne the last ',
#  ' delighted Anne. His good',
#  ' danger to Anne of meetin',
#  'going than Anne conceived',
#  'turning to Anne). “He fan',
#  'to believe Anne a greater',
#  'im mention Anne twice all',
#  'I declare, Anne, he never',
#  'intance of Anne’s will al',
#  's to being Anne’s acquain',
#  'ary,” said Anne. “I think',
#  'th, though Anne hazarded ',
#  'ussell and Anne were both',
#  'ussell and Anne paid thei',
#  'of course. Anne had alway',
#  'ood, which Anne could not',
#  'ent. Could Anne wonder th',
#  'lliot too. Anne had a gre',
#  'Mary); and Anne, smiling ',
#  'ections to Anne alone: he',
#  'oint which Anne, on retur',
#  'nest, that Anne was not s',
#  'e morning, Anne and her f',
#  ' appear to Anne that the ',
#  'ur, and of Anne so overlo',
#  'ears since Anne had begun',
#  'ure, which Anne, after a ',
#  '. In fact, Anne could nev',
#  'ymples (in Anne’s opinion',
#  '” and when Anne ventured ',
#  'eir value. Anne smiled an',
#  's,” sighed Anne, “we shal',
#  'ell,” said Anne, “I certa',
#  'ura Place, Anne was renew',
#  ' valuable. Anne had gone ',
#  'Smith, and Anne therefore',
#  'ldings, as Anne chose to ',
#  'ad changed Anne from the ',
#  ' all this, Anne had reaso',
#  'eaven; and Anne viewed he',
#  'ening, and Anne was alrea',
#  'ho is Miss Anne Elliot to',
#  'word, Miss Anne Elliot, y',
#  ',” replied Anne; “on the ',
#  'nd of Miss Anne Elliot, a',
#  ' room, and Anne could hav',
#  'erits; and Anne could not',
#  'ng to gain Anne in time a',
#  't speak to Anne with half',
#  'him,” said Anne; “but we ',
#  'My dearest Anne, it would',
#  '. This, to Anne, was a de',
#  'ruary; and Anne, having b',
#  'oint which Anne had not b',
#  'e farther, Anne ventured ',
#  'nity which Anne could not',
#  ' walk with Anne, and expr',
#  ' next time Anne walked ou',
#  'rifle, and Anne was most ',
#  ' than Miss Anne’s; and, i',
#  ' Elliot as Anne could be,',
#  'his cousin Anne’s boots w',
#  'oint, when Anne, as she s',
#  'heard, and Anne continuin',
#  'it grieved Anne to observ',
#  'd again to Anne, and by m',
#  ', I think; Anne Elliot; v',
#  'ng morning Anne was out w',
#  'gaged; and Anne, wearied ',
#  ' in alone. Anne was the n',
#  'support to Anne; she knew',
#  ' reddening Anne’s cheeks ',
#  'rther; and Anne who, in s',
#  ',” replied Anne; “but whe',
#  'zabeth and Anne Elliot as',
#  'reach; and Anne—but it wo',
#  ' nature of Anne’s felicit',
#  'ng of Miss Anne Elliot; a',
#  'on of Miss Anne Elliot as',
#  'he name of Anne Elliot,” ',
#  'his point, Anne’s eyes ha',
#  'st of tea. Anne was one o',
#  'e however. Anne sometimes',
#  'f her own, Anne was enabl',
#  'er obliged Anne to turn r',
#  'o be sung. Anne could not',
#  'for?” said Anne, suddenly',
#  'Bath, than Anne was sport',
#  'ore,” said Anne, consciou',
#  'overspread Anne’s cheeks.',
#  '” repeated Anne, looking ',
#  ',” replied Anne; “but I s',
#  ',” replied Anne, “nor nex',
#  '“No,” said Anne, “I can r',
#  'eyond; and Anne, eager to',
#  ' continued Anne, presentl',
#  'Nay,” said Anne, “I have ',
#  'ps,” cried Anne, struck b',
#  'ne,” cried Anne. “You hav',
#  'ut putting Anne in a glow',
#  'e, as Miss Anne Elliot, a',
#  'oment; but Anne had not a',
#  'Yes,” said Anne, “you tel',
#  'his,” said Anne, after a ',
#  'ction, and Anne had forgo',
#  'sband; but Anne could col',
#  'anity; and Anne felt, at ',
#  'ndulgence. Anne could per',
#  ' to engage Anne’s good of',
#  'o interest Anne’s feeling',
#  'Mr Elliot, Anne could not',
#  'ster, Miss Anne, seems be',
#  'es towards Anne. “Exactly',
#  's his; and Anne would hav',
#  'dmiration, Anne could not',
#  'ed,” cried Anne, “particu',
#  'china; but Anne had heard',
#  'rning; and Anne walked of',
#  'rity which Anne delighted',
#  'arcel; and Anne had not b',
#  'No,” cried Anne, quickly,',
#  'rself, but Anne did not m',
#  'Wentworth. Anne will not ',
#  'as life to Anne, who saw ',
#  'osing Miss Anne, too, if ',
#  'ed,” cried Anne, and stop',
#  'as left to Anne’s imagina',
#  'd to move. Anne talked of',
#  'stant; but Anne could ima',
#  'ssed since Anne’s convers',
#  'a whisper. Anne felt that',
#  ' sensibly. Anne hoped the',
#  'ation, but Anne heard not',
#  'indow, and Anne seeming t',
#  ',” replied Anne, in a low',
#  'rue,” said Anne, “very tr',
#  ',” replied Anne, “but the',
#  ' down; but Anne was start',
#  'smiling at Anne), “well s',
#  'Oh!” cried Anne eagerly, ',
#  'o be gone. Anne knew not ',
#  ' it before Anne with eyes',
#  'ad made in Anne, was almo',
#  'recaution, Anne struggled',
#  ' give Miss Anne’s message',
#  'ly looked. Anne could com',
#  ', and give Anne your arm ',
#  ',” replied Anne. “You sho',
#  'ght,” said Anne, “that my',
#  'ection for Anne, and no v',
#  'y Russell. Anne knew that',
#  ' She loved Anne better th',
#  'by keeping Anne with her ',
#  ' in seeing Anne restored ',
#  'his cousin Anne’s engagem',
#  'offices by Anne had been ',
#  'her heart. Anne was tende']

# %% [markdown]
# What are we getting back from Python here? Is it a string? How can we check?

# %%
type(anne_context)
# Out:
# list

# %% [markdown]
# Because this turns out to be a list, we can use **slicing** again, just like we did last week for strings. Slices work in lots of contexts in Python. For example to get the last mentions of Anne in _Persuasion_ we can do this:

# %%
anne_context[-10:-1]
# Out:
# ['e loved Anne better th',
#  'keeping Anne with her ',
#  ' seeing Anne restored ',
#  'lation. Anne had no',
#  'ns with Anne.',
#  ' cousin Anne’s engagem',
#  'Anne, satisfie',
#  'ices by Anne had been ',
#  'friend Anne’s was in ']

# %% [markdown]
# If you're ever unsure about the syntax for lists, create a small list of your own to check your intuition.

# %%
mylist = [1, 2, 3, 4, 5, 6]
mylist[-3:-1]
# Out:
# [4, 5]

# %%
mylist = [1, 2, 3, 4, 5, 6]
mylist[-1]
# Out:
# 6

# %%
mylist = [1, 2, 3, 4, 5, 6]
mylist[-5:]
# Out:
# [2, 3, 4, 5, 6]

# %% [markdown]
# With the regex, we can always add or subtract more full points to get more or less context.
#
# But there is a problem with the results of the regex. Since this is a list, we can get its length:
#
# --
#
# Got half of the "anne"s

# %%
len(anne_context)
# Out:
# 494

# %%
persuasion.count("Anne")
# Out:
# 496

# %% [markdown]
# These kinds of sense checks are good to build in to your thinking, and your code, as much as possible.

# %% [markdown]
# The next special character we'll use is ```?```, meaning _one or none_ of the preceding characters.

# %% [markdown]
# If we're not sure of the spelling of _Anne_ we can now allow for _Ann_ as well

# %%
anne_context = re.findall(r"..........Anne?..........", persuasion)

# %% [markdown]
# We can also use ```[^]``` to ask for any characters other than the ones after the ```^``` symbol.

# %%
no_anne_context = re.findall(r".......Ann[^e]+......", persuasion)

# %%
no_anne_context
# Out:
# []

# %% [markdown]
# But we can also use this to make the characters around our string optional. This is pretty crude but let's do it anyway:

# %%
anne_context = re.findall(r".?.?.?.?.?.?.?.?Anne.?.?.?.?.?.?.?.?.?.?", persuasion)

# %%
len(anne_context)
# Out:
# 494

# %% [markdown]
# A much better way is to give a range of how many characters we want to match, using ```{``` and ```}```.

# %%
anne_snippet = "Anne Elliot was doing a web search for herself. She wanted to find Anne and Anne's"

# %%
anne_snippet
# Out:
# "Anne Elliot was doing a web search for herself. She wanted to find Anne and Anne's"

# %%
anne_context = re.findall(r".{0,20}Anne.{0,20}", anne_snippet)
print(anne_context)
print(len(anne_context))
# Out:
# ['Anne Elliot was doing a ', " She wanted to find Anne and Anne's"]
# 2

# %%
anne_context = re.findall(r".{0,20}?Anne.{0,20}?", anne_snippet)
print(anne_context)
print(len(anne_context))
# Out:
# ['Anne', ' She wanted to find Anne', ' and Anne']
# 3

# %%
anne_words = re.findall(r"Anne [^ ]\w+", persuasion)

# %% [markdown]
# 'w'stands for word; '+' stands for more

# %%
anne_words
# Out:
# ['Anne that',
#  'Anne Elliot',
#  'Anne haggard',
#  'Anne and',
#  'Anne wanted',
#  'Anne attended',
#  'Anne herself',
#  'Anne had',
#  'Anne included',
#  'Anne spoke',
#  'Anne says',
#  'Anne an',
#  'Anne Elliot',
#  'Anne Elliot',
#  'Anne could',
#  'Anne was',
#  'Anne had',
#  'Anne Elliot',
#  'Anne found',
#  'Anne would',
#  'Anne though',
#  'Anne when',
#  'Anne had',
#  'Anne should',
#  'Anne could',
#  'Anne herself',
#  'Anne was',
#  'Anne had',
#  'Anne walked',
#  'Anne was',
#  'Anne had',
#  'Anne said',
#  'Anne had',
#  'Anne always',
#  'Anne very',
#  'Anne had',
#  'Anne could',
#  'Anne often',
#  'Anne was',
#  'Anne to',
#  'Anne had',
#  'Anne gave',
#  'Anne hoped',
#  'Anne was',
#  'Anne had',
#  'Anne will',
#  'Anne to',
#  'Anne followed',
#  'Anne will',
#  'Anne undertakes',
#  'Anne was',
#  'Anne understood',
#  'Anne were',
#  'Anne might',
#  'Anne fully',
#  'Anne Elliot',
#  'Anne Elliot',
#  'Anne Elliot',
#  'Anne Elliot',
#  'Anne felt',
#  'Anne could',
#  'Anne of',
#  'Anne suppressed',
#  'Anne offered',
#  'Anne did',
#  'Anne had',
#  'Anne Elliot',
#  'Anne had',
#  'Anne longed',
#  'Anne could',
#  'Anne felt',
#  'Anne have',
#  'Anne could',
#  'Anne found',
#  'Anne first',
#  'Anne if',
#  'Anne instead',
#  'Anne to',
#  'Anne distinguished',
#  'Anne could',
#  'Anne was',
#  'Anne was',
#  'Anne suspect',
#  'Anne to',
#  'Anne felt',
#  'Anne had',
#  'Anne thought',
#  'Anne found',
#  'Anne was',
#  'Anne could',
#  'Anne and',
#  'Anne smiled',
#  'Anne was',
#  'Anne Elliot',
#  'Anne felt',
#  'Anne quietly',
#  'Anne avoided',
#  'Anne found',
#  'Anne did',
#  'Anne found',
#  'Anne had',
#  'Anne walking',
#  'Anne was',
#  'Anne will',
#  'Anne was',
#  'Anne had',
#  'Anne wondered',
#  'Anne was',
#  'Anne found',
#  'Anne was',
#  'Anne thought',
#  'Anne was',
#  'Anne had',
#  'Anne would',
#  'Anne was',
#  'Anne Elliot',
#  'Anne did',
#  'Anne had',
#  'Anne the',
#  'Anne of',
#  'Anne conceived',
#  'Anne enquired',
#  'Anne twice',
#  'Anne hazarded',
#  'Anne were',
#  'Anne return',
#  'Anne paid',
#  'Anne did',
#  'Anne was',
#  'Anne entered',
#  'Anne had',
#  'Anne could',
#  'Anne wonder',
#  'Anne had',
#  'Anne listened',
#  'Anne mentioned',
#  'Anne was',
#  'Anne drew',
#  'Anne alone',
#  'Anne could',
#  'Anne was',
#  'Anne was',
#  'Anne and',
#  'Anne that',
#  'Anne so',
#  'Anne had',
#  'Anne presumed',
#  'Anne could',
#  'Anne had',
#  'Anne was',
#  'Anne ventured',
#  'Anne smiled',
#  'Anne could',
#  'Anne was',
#  'Anne had',
#  'Anne had',
#  'Anne therefore',
#  'Anne chose',
#  'Anne from',
#  'Anne found',
#  'Anne had',
#  'Anne viewed',
#  'Anne saw',
#  'Anne had',
#  'Anne was',
#  'Anne Elliot',
#  'Anne Elliot',
#  'Anne Elliot',
#  'Anne could',
#  'Anne kept',
#  'Anne had',
#  'Anne could',
#  'Anne in',
#  'Anne with',
#  'Anne heard',
#  'Anne was',
#  'Anne to',
#  'Anne in',
#  'Anne could',
#  'Anne was',
#  'Anne had',
#  'Anne was',
#  'Anne ventured',
#  'Anne had',
#  'Anne was',
#  'Anne could',
#  'Anne looked',
#  'Anne did',
#  'Anne walked',
#  'Anne was',
#  'Anne could',
#  'Anne continuing',
#  'Anne to',
#  'Anne as',
#  'Anne Elliot',
#  'Anne is',
#  'Anne would',
#  'Anne was',
#  'Anne sighed',
#  'Anne named',
#  'Anne was',
#  'Anne was',
#  'Anne who',
#  'Anne found',
#  'Anne Elliot',
#  'Anne saw',
#  'Anne Elliot',
#  'Anne was',
#  'Anne Elliot',
#  'Anne could',
#  'Anne Elliot',
#  'Anne was',
#  'Anne sometimes',
#  'Anne was',
#  'Anne to',
#  'Anne could',
#  'Anne recollected',
#  'Anne was',
#  'Anne half',
#  'Anne heard',
#  'Anne felt',
#  'Anne Elliot',
#  'Anne in',
#  'Anne could',
#  'Anne Elliot',
#  'Anne had',
#  'Anne had',
#  'Anne could',
#  'Anne was',
#  'Anne felt',
#  'Anne could',
#  'Anne could',
#  'Anne could',
#  'Anne had',
#  'Anne went',
#  'Anne admired',
#  'Anne herself',
#  'Anne would',
#  'Anne could',
#  'Anne could',
#  'Anne had',
#  'Anne walked',
#  'Anne convinced',
#  'Anne had',
#  'Anne delighted',
#  'Anne had',
#  'Anne to',
#  'Anne did',
#  'Anne did',
#  'Anne will',
#  'Anne could',
#  'Anne felt',
#  'Anne talked',
#  'Anne felt',
#  'Anne caught',
#  'Anne could',
#  'Anne felt',
#  'Anne hoped',
#  'Anne found',
#  'Anne heard',
#  'Anne seeming',
#  'Anne was',
#  'Anne eagerly',
#  'Anne knew',
#  'Anne with',
#  'Anne had',
#  'Anne struggled',
#  'Anne could',
#  'Anne could',
#  'Anne your',
#  'Anne smiled',
#  'Anne was',
#  'Anne knew',
#  'Anne happy',
#  'Anne better',
#  'Anne with',
#  'Anne restored',
#  'Anne had',
#  'Anne had',
#  'Anne was']

# %% [markdown]
# We already know that we're searching for the literal string "Anne" so maybe we want to exclude that from the results. You can do that with a slightly complicated regex, but instead let's use the other main type of loop: a for loop. A for loop loops over everything in a collection of things.

# %%
for word in anne_words:
    newword = word.replace("Anne", "")
    print(newword)
# Out:
#  that
#  Elliot
#  haggard
#  and
#  wanted
#  attended
#  herself
#  had
#  included
#  spoke
#  says
#  an
#  Elliot
#  Elliot
#  could
#  was
#  had
#  Elliot
#  found
#  would
#  though
#  when
#  had
#  should
#  could
#  herself
#  was
#  had
#  walked
#  was
#  had
#  said
#  had
#  always
#  very
#  had
#  could
#  often
#  was
#  to
#  had
#  gave
#  hoped
#  was
#  had
#  will
#  to
#  followed
#  will
#  undertakes
#  was
#  understood
#  were
#  might
#  fully
#  Elliot
#  Elliot
#  Elliot
#  Elliot
#  felt
#  could
#  of
#  suppressed
#  offered
#  did
#  had
#  Elliot
#  had
#  longed
#  could
#  felt
#  have
#  could
#  found
#  first
#  if
#  instead
#  to
#  distinguished
#  could
#  was
#  was
#  suspect
#  to
#  felt
#  had
#  thought
#  found
#  was
#  could
#  and
#  smiled
#  was
#  Elliot
#  felt
#  quietly
#  avoided
#  found
#  did
#  found
#  had
#  walking
#  was
#  will
#  was
#  had
#  wondered
#  was
#  found
#  was
#  thought
#  was
#  had
#  would
#  was
#  Elliot
#  did
#  had
#  the
#  of
#  conceived
#  enquired
#  twice
#  hazarded
#  were
#  return
#  paid
#  did
#  was
#  entered
#  had
#  could
#  wonder
#  had
#  listened
#  mentioned
#  was
#  drew
#  alone
#  could
#  was
#  was
#  and
#  that
#  so
#  had
#  presumed
#  could
#  had
#  was
#  ventured
#  smiled
#  could
#  was
#  had
#  had
#  therefore
#  chose
#  from
#  found
#  had
#  viewed
#  saw
#  had
#  was
#  Elliot
#  Elliot
#  Elliot
#  could
#  kept
#  had
#  could
#  in
#  with
#  heard
#  was
#  to
#  in
#  could
#  was
#  had
#  was
#  ventured
#  had
#  was
#  could
#  looked
#  did
#  walked
#  was
#  could
#  continuing
#  to
#  as
#  Elliot
#  is
#  would
#  was
#  sighed
#  named
#  was
#  was
#  who
#  found
#  Elliot
#  saw
#  Elliot
#  was
#  Elliot
#  could
#  Elliot
#  was
#  sometimes
#  was
#  to
#  could
#  recollected
#  was
#  half
#  heard
#  felt
#  Elliot
#  in
#  could
#  Elliot
#  had
#  had
#  could
#  was
#  felt
#  could
#  could
#  could
#  had
#  went
#  admired
#  herself
#  would
#  could
#  could
#  had
#  walked
#  convinced
#  had
#  delighted
#  had
#  to
#  did
#  did
#  will
#  could
#  felt
#  talked
#  felt
#  caught
#  could
#  felt
#  hoped
#  found
#  heard
#  seeming
#  was
#  eagerly
#  knew
#  with
#  had
#  struggled
#  could
#  could
#  your
#  smiled
#  was
#  knew
#  happy
#  better
#  with
#  restored
#  had
#  had
#  was

# %% [markdown]
# Last week we weren't sure if there were characters called _Annette_ or places called _Annecy_ in the text. With regex we can check that. Let's look for _A_ followed by any number of lower-case letters.
#
# Square brackets represent a _character class_, meaning _any one of these in any order_. ```[a-z]``` is a convenience to save you from typing ```[abcdefghijklmnopqrstuvwxyz]``` every time.
#
# ```+``` is like the ```?``` we saw above, but it means _one or more_.

# %%
capital_a = re.findall(r"A[a-z]+", persuasion)
capital_a
# Out:
# ['Author',
#  'Austen',
#  'Austen',
#  'Anne',
#  'August',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'All',
#  'Anne',
#  'Always',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'All',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'As',
#  'After',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'And',
#  'Admiral',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'And',
#  'Admiral',
#  'At',
#  'After',
#  'Anne',
#  'As',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'An',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'All',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Anne',
#  'Accordingly',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'As',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Again',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Anne',
#  'And',
#  'And',
#  'And',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Are',
#  'An',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Alas',
#  'And',
#  'Anne',
#  'Altered',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anybody',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Anne',
#  'Anne',
#  'Ah',
#  'Anne',
#  'Anne',
#  'Asp',
#  'Asp',
#  'Admiralty',
#  'Admiral',
#  'Asp',
#  'Admiral',
#  'Asp',
#  'Ah',
#  'Asp',
#  'Asp',
#  'Anne',
#  'And',
#  'Ah',
#  'And',
#  'Ah',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'All',
#  'Anne',
#  'All',
#  'Ah',
#  'Admiral',
#  'Ay',
#  'Atlantic',
#  'And',
#  'Admiral',
#  'Aye',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'And',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Another',
#  'Anne',
#  'Anne',
#  'After',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'After',
#  'Admiral',
#  'Ah',
#  'Admiral',
#  'And',
#  'Anne',
#  'After',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'After',
#  'Anne',
#  'Anne',
#  'Anne',
#  'After',
#  'Anne',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Ay',
#  'And',
#  'Anne',
#  'Admiral',
#  'Anne',
#  'Anne',
#  'Anne',
#  'After',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Abydos',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'After',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Ah',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'At',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Ay',
#  'And',
#  'August',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'At',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'An',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'At',
#  'Anne',
#  'Anne',
#  'Anne',
#  'An',
#  'Anne',
#  'As',
#  'Admiral',
#  'Ay',
#  'Admiral',
#  'Anne',
#  'Another',
#  'Ay',
#  'And',
#  'Anne',
#  'Admiral',
#  'Anne',
#  'Admiral',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'And',
#  'Any',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'After',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Allowances',
#  'All',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'As',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'As',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'At',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Are',
#  'And',
#  'And',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Anne',
#  'Admiral',
#  'Anne',
#  'Admiral',
#  'And',
#  'Admiral',
#  'Archibald',
#  'Ah',
#  'Archibald',
#  'Anne',
#  'Admiral',
#  'As',
#  'Anne',
#  'Ay',
#  'Anne',
#  'An',
#  'Anne',
#  'Admiral',
#  'And',
#  'Anne',
#  'Admiral',
#  'Anne',
#  'Anne',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'All',
#  'After',
#  'Anne',
#  'Anne',
#  'At',
#  'Anne',
#  'After',
#  'Anne',
#  'As',
#  'Atkinson',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Another',
#  'Anne',
#  'At',
#  'Alicia',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'After',
#  'All',
#  'Anne',
#  'After',
#  'Anne',
#  'About',
#  'Anne',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'An',
#  'Anne',
#  'All',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'After',
#  'Anne',
#  'Are',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'As',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'At',
#  'Anne',
#  'At',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'All',
#  'Anne',
#  'Anne',
#  'At',
#  'Anne',
#  'Anne',
#  'At',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'After',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'And',
#  'Anne',
#  'After',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Alicia',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'Anne',
#  'Anne',
#  'As',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'After',
#  'Anne',
#  'Anne',
#  'Alarming',
#  'Anne',
#  'After',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'And',
#  'At',
#  'Anne',
#  'Anne',
#  'Anne',
#  'As',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Ah',
#  'And',
#  'Anne',
#  'All',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anything',
#  'And',
#  'Anne',
#  'Anxious',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Another',
#  'Anne',
#  'Are',
#  'Are',
#  'Anne',
#  'And',
#  'All',
#  'At',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'At',
#  'Anne',
#  'All',
#  'An',
#  'Anne',
#  'Admiral',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Archive',
#  'Additional',
#  'Any',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'About',
#  'Archive']

# %%
capital_a.sort()
capital_a
# Out:
# ['About',
#  'About',
#  'Abydos',
#  'Accordingly',
#  'Additional',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiral',
#  'Admiralty',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'After',
#  'Again',
#  'Ah',
#  'Ah',
#  'Ah',
#  'Ah',
#  'Ah',
#  'Ah',
#  'Ah',
#  'Ah',
#  'Ah',
#  'Alarming',
#  'Alas',
#  'Alicia',
#  'Alicia',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'All',
#  'Allowances',
#  'Altered',
#  'Always',
#  'An',
#  'An',
#  'An',
#  'An',
#  'An',
#  'An',
#  'An',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'And',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Anne',
#  'Another',
#  'Another',
#  'Another',
#  'Another',
#  'Anxious',
#  'Any',
#  'Any',
#  'Anybody',
#  'Anything',
#  'Archibald',
#  'Archibald',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Archive',
#  'Are',
#  'Are',
#  'Are',
#  'Are',
#  'Are',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'As',
#  'Asp',
#  'Asp',
#  'Asp',
#  'Asp',
#  'Asp',
#  'Asp',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'At',
#  'Atkinson',
#  'Atlantic',
#  'August',
#  'August',
#  'Austen',
#  'Austen',
#  'Author',
#  'Ay',
#  'Ay',
#  'Ay',
#  'Ay',
#  'Ay',
#  'Ay',
#  'Aye']

# %%
set(capital_a)
# Out:
# {'About',
#  'Abydos',
#  'Accordingly',
#  'Additional',
#  'Admiral',
#  'Admiralty',
#  'After',
#  'Again',
#  'Ah',
#  'Alarming',
#  'Alas',
#  'Alicia',
#  'All',
#  'Allowances',
#  'Altered',
#  'Always',
#  'An',
#  'And',
#  'Anne',
#  'Another',
#  'Anxious',
#  'Any',
#  'Anybody',
#  'Anything',
#  'Archibald',
#  'Archive',
#  'Are',
#  'As',
#  'Asp',
#  'At',
#  'Atkinson',
#  'Atlantic',
#  'August',
#  'Austen',
#  'Author',
#  'Ay',
#  'Aye'}

# %% [markdown]
# So there are, apparently, characters called _Alicia_, _Archibald_ and _Atkinson_.

# %%
len(set(capital_a))
# Out:
# 37

# %% [markdown]
# Can we use regex to look at all the verbs associated with Anne in _Persuasion_? Here's a first attempt:

# %%
annes_verbs = re.findall(r"Anne [^ ]+ed\W", persuasion)

# %%
annes_verbs
# Out:
# ['Anne wanted ',
#  'Anne attended ',
#  'Anne included ',
#  'Anne walked ',
#  'Anne hoped ',
#  'Anne followed ',
#  'Anne suppressed ',
#  'Anne offered ',
#  'Anne longed ',
#  'Anne felt\npersuaded,',
#  'Anne distinguished ',
#  'Anne smiled ',
#  'Anne avoided ',
#  'Anne wondered ',
#  'Anne conceived ',
#  'Anne enquired ',
#  'Anne hazarded ',
#  'Anne entered ',
#  'Anne listened,',
#  'Anne mentioned ',
#  'Anne presumed,',
#  'Anne ventured ',
#  'Anne smiled ',
#  'Anne viewed ',
#  'Anne ventured ',
#  'Anne looked ',
#  'Anne walked ',
#  'Anne sighed ',
#  'Anne named ',
#  'Anne recollected ',
#  'Anne admired ',
#  'Anne walked ',
#  'Anne convinced ',
#  'Anne delighted ',
#  'Anne talked ',
#  'Anne hoped ',
#  'Anne struggled,',
#  'Anne smiled,',
#  'Anne restored ']

# %% [markdown]
# These aren't, of course, all of Anne's verbs. Regex only operates on sequences of characters.

# %% [markdown]
# We've now seen quite a lot of the regex syntax you'll ever need to find things with. To sum up:
#
# ```.``` any character
#
# ```+``` one or more of the preceding (by default, matches as much as possible: 'greedy')
#
# ```?``` one or none of the preceding
#
# ```*``` one or none of the preceding (by default, matches as much as possible: 'greedy')
#
# ```[]``` a character class, 'find any of these, in any order'
#
# ```[^]``` a negated character class 'find anything that is not one of these'
#
# What about if you want to find literal versions of the above, like a literal full stop?
#
# Put a ```\``` in front of it to _escape_ it: make it not special. For example ```\?``` matches a literal question mark.
#
# #### some shortcuts
#
# ```\w``` any non-whitespace character  匹配字母、数字、下划线。
#
# ```\W``` any whitespace character, including punctuation 匹配非字母、数字、下划线。
#
# ```[0-9]``` any number
#
# ```[a-z]``` any lowercase letter
#
# ```[A-Z]``` any uppercase letter

# %% [markdown]
# But if you're new to regex this will still be a lot to take in. Practice is the only way to learning regex, so don't worry. The key thing is to remember that there are many situations where regex will make your life easier and you can look up the syntax any time you need to.

# %% [markdown]
# Last week, splitting on whitespace was too crude for us to get all the words from _Persuasion_. Regex allows us to fix that.

# %%
persuasion_words = re.findall(r'\w+', persuasion)

# %%
persuasion_words
# Out:
# ['The',
#  'Project',
#  'Gutenberg',
#  'eBook',
#  'of',
#  'Persuasion',
#  'This',
#  'ebook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'in',
#  'the',
#  'United',
#  'States',
#  'and',
#  'most',
#  'other',
#  'parts',
#  'of',
#  'the',
#  'world',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever',
#  'You',
#  'may',
#  'copy',
#  'it',
#  'give',
#  'it',
#  'away',
#  'or',
#  're',
#  'use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License',
#  'included',
#  'with',
#  'this',
#  'ebook',
#  'or',
#  'online',
#  'at',
#  'www',
#  'gutenberg',
#  'org',
#  'If',
#  'you',
#  'are',
#  'not',
#  'located',
#  'in',
#  'the',
#  'United',
#  'States',
#  'you',
#  'will',
#  'have',
#  'to',
#  'check',
#  'the',
#  'laws',
#  'of',
#  'the',
#  'country',
#  'where',
#  'you',
#  'are',
#  'located',
#  'before',
#  'using',
#  'this',
#  'eBook',
#  'Title',
#  'Persuasion',
#  'Author',
#  'Jane',
#  'Austen',
#  'Release',
#  'date',
#  'February',
#  '1',
#  '1994',
#  'eBook',
#  '105',
#  'Most',
#  'recently',
#  'updated',
#  'September',
#  '10',
#  '2023',
#  'Language',
#  'English',
#  'Credits',
#  'Sharon',
#  'Partridge',
#  'and',
#  'Martin',
#  'Ward',
#  'Revised',
#  'by',
#  'Richard',
#  'Tonsing',
#  'START',
#  'OF',
#  'THE',
#  'PROJECT',
#  'GUTENBERG',
#  'EBOOK',
#  'PERSUASION',
#  'Persuasion',
#  'by',
#  'Jane',
#  'Austen',
#  '1818',
#  'Contents',
#  'CHAPTER',
#  'I',
#  'CHAPTER',
#  'II',
#  'CHAPTER',
#  'III',
#  'CHAPTER',
#  'IV',
#  'CHAPTER',
#  'V',
#  'CHAPTER',
#  'VI',
#  'CHAPTER',
#  'VII',
#  'CHAPTER',
#  'VIII',
#  'CHAPTER',
#  'IX',
#  'CHAPTER',
#  'X',
#  'CHAPTER',
#  'XI',
#  'CHAPTER',
#  'XII',
#  'CHAPTER',
#  'XIII',
#  'CHAPTER',
#  'XIV',
#  'CHAPTER',
#  'XV',
#  'CHAPTER',
#  'XVI',
#  'CHAPTER',
#  'XVII',
#  'CHAPTER',
#  'XVIII',
#  'CHAPTER',
#  'XIX',
#  'CHAPTER',
#  'XX',
#  'CHAPTER',
#  'XXI',
#  'CHAPTER',
#  'XXII',
#  'CHAPTER',
#  'XXIII',
#  'CHAPTER',
#  'XXIV',
#  'CHAPTER',
#  'I',
#  'Sir',
#  'Walter',
#  'Elliot',
#  'of',
#  'Kellynch',
#  'Hall',
#  'in',
#  'Somersetshire',
#  'was',
#  'a',
#  'man',
#  'who',
#  'for',
#  'his',
#  'own',
#  'amusement',
#  'never',
#  'took',
#  'up',
#  'any',
#  'book',
#  'but',
#  'the',
#  'Baronetage',
#  'there',
#  'he',
#  'found',
#  'occupation',
#  'for',
#  'an',
#  'idle',
#  'hour',
#  'and',
#  'consolation',
#  'in',
#  'a',
#  'distressed',
#  'one',
#  'there',
#  'his',
#  'faculties',
#  'were',
#  'roused',
#  'into',
#  'admiration',
#  'and',
#  'respect',
#  'by',
#  'contemplating',
#  'the',
#  'limited',
#  'remnant',
#  'of',
#  'the',
#  'earliest',
#  'patents',
#  'there',
#  'any',
#  'unwelcome',
#  'sensations',
#  'arising',
#  'from',
#  'domestic',
#  'affairs',
#  'changed',
#  'naturally',
#  'into',
#  'pity',
#  'and',
#  'contempt',
#  'as',
#  'he',
#  'turned',
#  'over',
#  'the',
#  'almost',
#  'endless',
#  'creations',
#  'of',
#  'the',
#  'last',
#  'century',
#  'and',
#  'there',
#  'if',
#  'every',
#  'other',
#  'leaf',
#  'were',
#  'powerless',
#  'he',
#  'could',
#  'read',
#  'his',
#  'own',
#  'history',
#  'with',
#  'an',
#  'interest',
#  'which',
#  'never',
#  'failed',
#  'This',
#  'was',
#  'the',
#  'page',
#  'at',
#  'which',
#  'the',
#  'favourite',
#  'volume',
#  'always',
#  'opened',
#  'ELLIOT',
#  'OF',
#  'KELLYNCH',
#  'HALL',
#  'Walter',
#  'Elliot',
#  'born',
#  'March',
#  '1',
#  '1760',
#  'married',
#  'July',
#  '15',
#  '1784',
#  'Elizabeth',
#  'daughter',
#  'of',
#  'James',
#  'Stevenson',
#  'Esq',
#  'of',
#  'South',
#  'Park',
#  'in',
#  'the',
#  'county',
#  'of',
#  'Gloucester',
#  'by',
#  'which',
#  'lady',
#  'who',
#  'died',
#  '1800',
#  'he',
#  'has',
#  'issue',
#  'Elizabeth',
#  'born',
#  'June',
#  '1',
#  '1785',
#  'Anne',
#  'born',
#  'August',
#  '9',
#  '1787',
#  'a',
#  'still',
#  'born',
#  'son',
#  'November',
#  '5',
#  '1789',
#  'Mary',
#  'born',
#  'November',
#  '20',
#  '1791',
#  'Precisely',
#  'such',
#  'had',
#  'the',
#  'paragraph',
#  'originally',
#  'stood',
#  'from',
#  'the',
#  'printer',
#  's',
#  'hands',
#  'but',
#  'Sir',
#  'Walter',
#  'had',
#  'improved',
#  'it',
#  'by',
#  'adding',
#  'for',
#  'the',
#  'information',
#  'of',
#  'himself',
#  'and',
#  'his',
#  'family',
#  'these',
#  'words',
#  'after',
#  'the',
#  'date',
#  'of',
#  'Mary',
#  's',
#  'birth',
#  'Married',
#  'December',
#  '16',
#  '1810',
#  'Charles',
#  'son',
#  'and',
#  'heir',
#  'of',
#  'Charles',
#  'Musgrove',
#  'Esq',
#  'of',
#  'Uppercross',
#  'in',
#  'the',
#  'county',
#  'of',
#  'Somerset',
#  'and',
#  'by',
#  'inserting',
#  'most',
#  'accurately',
#  'the',
#  'day',
#  'of',
#  'the',
#  'month',
#  'on',
#  'which',
#  'he',
#  'had',
#  'lost',
#  'his',
#  'wife',
#  'Then',
#  'followed',
#  'the',
#  'history',
#  'and',
#  'rise',
#  'of',
#  'the',
#  'ancient',
#  'and',
#  'respectable',
#  'family',
#  'in',
#  'the',
#  'usual',
#  'terms',
#  'how',
#  'it',
#  'had',
#  'been',
#  'first',
#  'settled',
#  'in',
#  'Cheshire',
#  'how',
#  'mentioned',
#  'in',
#  'Dugdale',
#  'serving',
#  'the',
#  'office',
#  'of',
#  'high',
#  'sheriff',
#  'representing',
#  'a',
#  'borough',
#  'in',
#  'three',
#  'successive',
#  'parliaments',
#  'exertions',
#  'of',
#  'loyalty',
#  'and',
#  'dignity',
#  'of',
#  'baronet',
#  'in',
#  'the',
#  'first',
#  'year',
#  'of',
#  'Charles',
#  'II',
#  'with',
#  'all',
#  'the',
#  'Marys',
#  'and',
#  'Elizabeths',
#  'they',
#  'had',
#  'married',
#  'forming',
#  'altogether',
#  'two',
#  'handsome',
#  'duodecimo',
#  'pages',
#  'and',
#  'concluding',
#  'with',
#  'the',
#  'arms',
#  'and',
#  'motto',
#  'Principal',
#  'seat',
#  'Kellynch',
#  'Hall',
#  'in',
#  'the',
#  'county',
#  'of',
#  'Somerset',
#  'and',
#  'Sir',
#  'Walter',
#  's',
#  'handwriting',
#  'again',
#  'in',
#  'this',
#  'finale',
#  'Heir',
#  'presumptive',
#  'William',
#  'Walter',
#  'Elliot',
#  'Esq',
#  'great',
#  'grandson',
#  'of',
#  'the',
#  'second',
#  'Sir',
#  'Walter',
#  'Vanity',
#  'was',
#  'the',
#  'beginning',
#  'and',
#  'the',
#  'end',
#  'of',
#  'Sir',
#  'Walter',
#  'Elliot',
#  's',
#  'character',
#  'vanity',
#  'of',
#  'person',
#  'and',
#  'of',
#  'situation',
#  'He',
#  'had',
#  'been',
#  'remarkably',
#  'handsome',
#  'in',
#  'his',
#  'youth',
#  'and',
#  'at',
#  'fifty',
#  'four',
#  'was',
#  'still',
#  'a',
#  'very',
#  'fine',
#  'man',
#  'Few',
#  'women',
#  'could',
#  'think',
#  'more',
#  'of',
#  'their',
#  'personal',
#  'appearance',
#  'than',
#  'he',
#  'did',
#  'nor',
#  'could',
#  'the',
#  'valet',
#  'of',
#  'any',
#  'new',
#  'made',
#  'lord',
#  'be',
#  'more',
#  'delighted',
#  'with',
#  'the',
#  'place',
#  'he',
#  'held',
#  'in',
#  'society',
#  'He',
#  'considered',
#  'the',
#  'blessing',
#  'of',
#  'beauty',
#  'as',
#  'inferior',
#  'only',
#  'to',
#  'the',
#  'blessing',
#  'of',
#  'a',
#  'baronetcy',
#  'and',
#  'the',
#  'Sir',
#  'Walter',
#  'Elliot',
#  'who',
#  'united',
#  'these',
#  'gifts',
#  'was',
#  'the',
#  'constant',
#  'object',
#  'of',
#  'his',
#  'warmest',
#  'respect',
#  'and',
#  'devotion',
#  'His',
#  'good',
#  'looks',
#  'and',
#  'his',
#  'rank',
#  'had',
#  'one',
#  'fair',
#  'claim',
#  'on',
#  'his',
#  'attachment',
#  'since',
#  'to',
#  'them',
#  'he',
#  'must',
#  'have',
#  'owed',
#  'a',
#  'wife',
#  'of',
#  'very',
#  'superior',
#  'character',
#  'to',
#  'any',
#  'thing',
#  'deserved',
#  'by',
#  'his',
#  'own',
#  'Lady',
#  'Elliot',
#  'had',
#  'been',
#  'an',
#  'excellent',
#  'woman',
#  'sensible',
#  'and',
#  'amiable',
#  'whose',
#  'judgement',
#  'and',
#  'conduct',
#  'if',
#  'they',
#  'might',
#  'be',
#  'pardoned',
#  'the',
#  'youthful',
#  'infatuation',
#  'which',
#  'made',
#  'her',
#  'Lady',
#  'Elliot',
#  'had',
#  'never',
#  'required',
#  'indulgence',
#  'afterwards',
#  'She',
#  'had',
#  'humoured',
#  'or',
#  'softened',
#  'or',
#  'concealed',
#  'his',
#  'failings',
#  'and',
#  'promoted',
#  'his',
#  'real',
#  'respectability',
#  'for',
#  'seventeen',
#  'years',
#  'and',
#  'though',
#  'not',
#  'the',
#  'very',
#  'happiest',
#  'being',
#  'in',
#  'the',
#  'world',
#  'herself',
#  'had',
#  'found',
#  'enough',
#  'in',
#  'her',
#  'duties',
#  'her',
#  'friends',
#  'and',
#  'her',
#  'children',
#  'to',
#  'attach',
#  'her',
#  'to',
#  'life',
#  'and',
#  'make',
#  'it',
#  'no',
#  'matter',
#  'of',
#  'indifference',
#  'to',
#  'her',
#  'when',
#  'she',
#  'was',
#  'called',
#  'on',
#  'to',
#  'quit',
#  'them',
#  'Three',
#  'girls',
#  'the',
#  'two',
#  'eldest',
#  'sixteen',
#  'and',
#  'fourteen',
#  'was',
#  'an',
#  'awful',
#  'legacy',
#  'for',
#  'a',
#  'mother',
#  'to',
#  'bequeath',
#  'an',
#  'awful',
#  'charge',
#  'rather',
#  'to',
#  'confide',
#  'to',
#  'the',
#  'authority',
#  'and',
#  'guidance',
#  'of',
#  'a',
#  'conceited',
#  'silly',
#  'father',
#  'She',
#  'had',
#  'however',
#  'one',
#  'very',
#  'intimate',
#  'friend',
#  'a',
#  'sensible',
#  'deserving',
#  'woman',
#  'who',
#  'had',
#  'been',
#  'brought',
#  'by',
#  'strong',
#  'attachment',
#  'to',
#  'herself',
#  'to',
#  'settle',
#  'close',
#  'by',
#  'her',
#  'in',
#  'the',
#  'village',
#  'of',
#  'Kellynch',
#  'and',
#  'on',
#  'her',
#  'kindness',
#  'and',
#  'advice',
#  'Lady',
#  'Elliot',
#  'mainly',
#  'relied',
#  'for',
#  'the',
#  'best',
#  'help',
#  'and',
#  'maintenance',
#  'of',
#  'the',
#  'good',
#  'principles',
#  'and',
#  'instruction',
#  'which',
#  'she',
#  'had',
#  'been',
#  'anxiously',
#  'giving',
#  'her',
#  'daughters',
#  'This',
#  'friend',
#  'and',
#  'Sir',
#  'Walter',
#  'did',
#  'not',
#  'marry',
#  'whatever',
#  'might',
#  'have',
#  'been',
#  'anticipated',
#  'on',
#  'that',
#  'head',
#  'by',
#  'their',
#  'acquaintance',
#  'Thirteen',
#  'years',
#  'had',
#  'passed',
#  'away',
#  'since',
#  'Lady',
#  'Elliot',
#  's',
#  'death',
#  'and',
#  'they',
#  'were',
#  'still',
#  'near',
#  'neighbours',
#  'and',
#  'intimate',
#  'friends',
#  'and',
#  'one',
#  'remained',
#  'a',
#  'widower',
#  'the',
#  'other',
#  'a',
#  'widow',
#  'That',
#  'Lady',
#  'Russell',
#  'of',
#  'steady',
#  'age',
#  'and',
#  'character',
#  'and',
#  'extremely',
#  'well',
#  'provided',
#  'for',
#  'should',
#  'have',
#  'no',
#  'thought',
#  'of',
#  'a',
#  'second',
#  'marriage',
#  'needs',
#  'no',
#  'apology',
#  'to',
#  'the',
#  'public',
#  'which',
#  'is',
#  'rather',
#  'apt',
#  'to',
#  'be',
#  'unreasonably',
#  'discontented',
#  'when',
#  'a',
#  'woman',
#  '_does_',
#  'marry',
#  'again',
#  'than',
#  'when',
#  'she',
#  'does',
#  '_not',
#  '_',
#  'but',
#  'Sir',
#  'Walter',
#  's',
#  'continuing',
#  'in',
#  'singleness',
#  'requires',
#  'explanation',
#  'Be',
#  'it',
#  'known',
#  'then',
#  'that',
#  'Sir',
#  'Walter',
#  'like',
#  'a',
#  'good',
#  'father',
#  'having',
#  'met',
#  'with',
#  'one',
#  'or',
#  'two',
#  'private',
#  'disappointments',
#  'in',
#  'very',
#  'unreasonable',
#  'applications',
#  'prided',
#  'himself',
#  'on',
#  'remaining',
#  'single',
#  'for',
#  'his',
#  'dear',
#  'daughters',
#  'sake',
#  'For',
#  'one',
#  'daughter',
#  'his',
#  'eldest',
#  'he',
#  ...]

# %%
biggest_words = sorted(persuasion_words, key=len, reverse=True)

# %%
biggest_words[:10]
# Out:
# ['unreasonableness',
#  'incomprehensible',
#  'misconstructions',
#  'acknowledgements',
#  'unenforceability',
#  'disappointments',
#  'disrespectfully',
#  'accomplishments',
#  'undesirableness',
#  'unexceptionable']

# %%
from collections import Counter

# %%
mycounts = Counter(persuasion_words)
mycounts.most_common(10) # or whatever number required
# Out:
# [('the', 3290),
#  ('to', 2852),
#  ('and', 2804),
#  ('of', 2675),
#  ('a', 1586),
#  ('in', 1404),
#  ('was', 1332),
#  ('had', 1176),
#  ('her', 1156),
#  ('I', 1125)]

# %% [markdown]
# What about replacing? For that, in Python, we use ```re.sub```. It works the same way as ```findall``` but we need an extra argument to the function: the thing we want to put in place of what we found. As always, the simplest possible example is a good place to start.

# %% [markdown]
# Eliot 可能会拼成Eliot / Elliot

# %%
sample = "Anne Elliot"
print(sample)
sample = re.sub(r"Anne? El+iot+", "the principal character", sample)
print(sample)
# Out:
# Anne Elliot
# the principal character

# %% [markdown]
# The most powerful part of replacement is re-using parts of the find, for example to add to them or move them around.
#
# To do this, put round brackets around a part of the regex you want to recall in the replacement, this is known as a _capture group_.
#
# In the replacement text the contents of the first set of brackets are referred to with ```\\1```, the second set as ```\\2``` and so on. In regex this is known as a _back reference_.

# %%
sample = "Anne Elliot"
print(sample)
print("But let's swap the names around:")
sample = re.sub(r"(Anne?) (El+iot+)", "\\2, \\1", sample)
print(sample)
# Out:
# Anne Elliot
# But let's swap the names around:
# Elliot, Anne

# %% [markdown]
# When not to use regular expressions.
#
# Because regex work on strings, they cannot reliably _parse_ data, that is work with its structure.
#
# Once you get good at regex, you might be tempted to use it to parse structured data. Here's a simple example of data in _CSV_ (_comma-separated values_) format:
# ```
# character,novel,occurence_count
# Anne Elliot,Persuasion,486
# Emma Woodhouse,Emma,397
# Elizabeth Bennett,Pride and Prejudice,292
# Fanny Price,Mansfield Park,331
# ```
#
# If you try to extract the middle column you will be trying to parse the data with regex. This is highly unreliable and inadvisable.

# %% [markdown]
# Regex doesn't work for structure; but look for characters

# %% [markdown]
# ### Group work

# %% [markdown]
# #### finding
#
# 1. Find the context around another main character in _Persuasion_, Captain Wentworth.
#
# 2. Does Captain ever get abbreviated to _Capt._?
#
# 3. Find the word following _Anne_. Can you make a unique list of these? Can you take account of punctuation between _Anne_ and the following word?
#
# 4. Can you create an alphabetised list of all 9-letter words in _Persuasion_?
#
# 5. By default in Python, a ```.``` won't run past a ```\n``` character. Can you modify one of the above searches to include characters from the next line? You might need to look at the ```re``` (https://docs.python.org/3/library/re.html)[documentation] for the answer to this.
#
# #### replacing
#
# Use ```re.sub``` to replace some text in ```persuasion```. If you work on the whole novel, Python will have no trouble with this, but it might be hard to see the results. You might prefer to create a slice of Persuasion of a few hundred characters, so you can see the output of your replacement more easily.
#
# This will overwrite the text of ```persuasion```, so if you prefer you can create a string with a different variable name, eg:
#
# ```modified_persuasion = re.sub(r"search string", "replacement", persuasion)```
#
#
# #### finally
#
# Can you explain why, above, we got slightly more results for ```persuasion.count("Anne")```, when compared to ```re.findall(r"{0,20}Anne{0,20}, persuasion)```? This is a bit tricky! Maybe create a small text of your own to test the way these two behave.
