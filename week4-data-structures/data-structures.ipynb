# %% [markdown]
# ### Data types
#
# In Python, especially in DH, we are often manipulating data. You often need to ask yourself: what data type is it  currently and what data type do I need it to be?

# %% [markdown]
# When you create a *variable* Python infers its type, which then affects what you can do with it. You can use string methods on strings, as we did in week 1, but you have to use integer methods on integers.
#
# The main types are: *string*, *integer*, *float*, *Boolean*.

# %%
name = "Taylor Swift"
age = 35
shoe_size = 9.0
is_famous = True

# %%
print(type(name))
print(type(age))
print(type(shoe_size))
print(type(is_famous))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# If we want to use a method bound to a different data type we can change the data type. Lots of data in DH comes as strings.

# %%
Swift_born = "1989"
current_year = 2025

# %%
current_year - Swift_born
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1771596028.py in <cell line: 0>()
# ----> 1 current_year - Swift_born
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
current_year - int(Swift_born)
# Out:
# 36

# %% [markdown]
# How can we make this correct without doing a fancy calculation based on Swift's exact age?

# %%
print(f"Taylor Swift is either {current_year - int(Swift_born)} or {current_year - int(Swift_born) - 1}.")
# Out:
# Taylor Swift is either 36 or 35.

# %% [markdown]
# Python also has container datatypes known as *Collections*. The ones to be comfortable with are *list*, *tuple*, *set* and *dictionary*.

# %% [markdown]
# Lists go in square brackets. They're a good data type to learn first because they match our natural intuition for lists. If you have a to-do list you can delete completed items and add new ones. If a task becomes more important you can move it up the list. In Python's terminology, this means they are *mutable*. They are also *ordered*. Here the order is chronological.
#
# list can mix different types of data

# %%
Austen_novels = ["Sense and Sensibility", "Pride and Prejudice", "Mansfield Park", "Emma", "Northanger Abbey", "Persuasion"]

# %%
Austen_novels[0]
# Out:
# 'Sense and Sensibility'

# %%
Austen_novels[1]
# Out:
# 'Pride and Prejudice'

# %% [markdown]
# A Python list (and counting generally) **starts at 0.** Getting this wrong is very common in coding, not just in Python. It's called the off-by-one error.

# %% [markdown]
# how to make new list;  set up -- blank brackets []
#
# List of comprehension

# %%
unfinished = []

# %%
unfinished.append("Sanditon")
unfinished.append("The Watsons")

# %%
unfinished
# Out:
# ['Sanditon', 'The Watsons']

# %%
all_works = Austen_novels + unfinished

# %%
all_works
# Out:
# ['Sense and Sensibility',
#  'Pride and Prejudice',
#  'Mansfield Park',
#  'Emma',
#  'Northanger Abbey',
#  'Persuasion',
#  'Sanditon',
#  'The Watsons']

# %% [markdown]
# It's generally good to keep the older lists rather than mutate one list. We could do:
#
# `Austen_novels = Austen_novels + unfinished`
#
# But then we have no easy way to recover just the finished novels. This is true of all data in Python, unless you start to get really big datasets to store.

# %% [markdown]
# As we've seen in previous weeks, we can loop over a list with a for loop. This is called a `list comprehension` (because Python does the work of making sure every item in the list is handled).

# %%
for novel in Austen_novels:
    print(f"Austen wrote {novel}.")
# Out:
# Austen wrote Sense and Sensibility.
# Austen wrote Pride and Prejudice.
# Austen wrote Mansfield Park.
# Austen wrote Emma.
# Austen wrote Northanger Abbey.
# Austen wrote Persuasion.

# %% [markdown]
# We can add logic to a list comprehension, to split items into different lists, filter out items, or just print them out slightly differently. This if/else syntax can be used in Python generally, not just in list comprehensions.

# %%
for novel in Austen_novels:
    if novel == Austen_novels[0]:
        print(f"First, Austen published {novel}.")
    elif novel == Austen_novels[-1]:
        print(f"After Austen's death {novel} was published.")
    else:
        print(f"Then she published {novel}.")
# Out:
# First, Austen published Sense and Sensibility.
# Then she published Pride and Prejudice.
# Then she published Mansfield Park.
# Then she published Emma.
# Then she published Northanger Abbey.
# After Austen's death Persuasion was published.

# %% [markdown]
# Lists are ordered, mutable and can have duplicates. They are often a good choice if you're not sure which structure you want.
#
# But if we want to compare the vocabulary used in different Austen novels, eg to find out which words are *only* used in Northanger Abbey, lists would be a painfully slow way to do it. For this task **we don't care about the order of the words and we don't care about duplicates.** This calls for a **set**. A set in Python is mutable, unordered and has no duplicates. Sets are fast precisely because they are unordered. Think about how quickly people board a bus (unordered) compared to a plane (ordered).

# %%
some_numbers = [1, 5, 3, 1, 5, 2, 3, 1, 1, 9, 2, 3, 1, 9, 2, 1, 3]
set(some_numbers)
# Out:
# {1, 2, 3, 5, 9}

# %%
set(some_numbers)[0] # you can't do this with sets!
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2047784237.py in <cell line: 0>()
# ----> 1 set(some_numbers)[0] # you can't do this with sets!
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# Let's get six sets of the words in the Austen novels.

# %%
# !wget https://raw.githubusercontent.com/jonathanblaney/RSE-dropins-2025-6/refs/heads/main/week1-plain-text/emma.txt
# !wget https://raw.githubusercontent.com/jonathanblaney/RSE-dropins-2025-6/refs/heads/main/week1-plain-text/persuasion.txt
# !wget https://raw.githubusercontent.com/jonathanblaney/RSE-dropins-2025-6/refs/heads/main/week3-cli/mansfield_park.txt
# !wget https://raw.githubusercontent.com/jonathanblaney/RSE-dropins-2025-6/refs/heads/main/week3-cli/northanger_abbey.txt
# !wget https://raw.githubusercontent.com/jonathanblaney/RSE-dropins-2025-6/refs/heads/main/week3-cli/pride_and_prejudice.txt
# !wget https://raw.githubusercontent.com/jonathanblaney/RSE-dropins-2025-6/refs/heads/main/week3-cli/sense_and_sensibility.txt
# Out:
# --2025-11-03 15:26:27--  https://raw.githubusercontent.com/jonathanblaney/RSE-dropins-2025-6/refs/heads/main/week1-plain-text/emma.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 933759 (912K) [text/plain]
# Saving to: ‘emma.txt’
#
# emma.txt            100%[===================>] 911.87K  --.-KB/s    in 0.02s
#
# 2025-11-03 15:26:27 (48.7 MB/s) - ‘emma.txt’ saved [933759/933759]
#
# --2025-11-03 15:26:27--  https://raw.githubusercontent.com/jonathanblaney/RSE-dropins-2025-6/refs/heads/main/week1-plain-text/persuasion.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 497612 (486K) [text/plain]
# Saving to: ‘persuasion.txt’
#
# persuasion.txt      100%[===================>] 485.95K  --.-KB/s    in 0.02s
#
# 2025-11-03 15:26:28 (31.0 MB/s) - ‘persuasion.txt’ saved [497612/497612]
#
# --2025-11-03 15:26:28--  https://raw.githubusercontent.com/jonathanblaney/RSE-dropins-2025-6/refs/heads/main/week3-cli/mansfield_park.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 928771 (907K) [text/plain]
# Saving to: ‘mansfield_park.txt’
#
# mansfield_park.txt  100%[===================>] 907.00K  --.-KB/s    in 0.02s
#
# 2025-11-03 15:26:28 (50.5 MB/s) - ‘mansfield_park.txt’ saved [928771/928771]
#
# --2025-11-03 15:26:28--  https://raw.githubusercontent.com/jonathanblaney/RSE-dropins-2025-6/refs/heads/main/week3-cli/northanger_abbey.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 468091 (457K) [text/plain]
# Saving to: ‘northanger_abbey.txt’
#
# northanger_abbey.tx 100%[===================>] 457.12K  --.-KB/s    in 0.01s
#
# 2025-11-03 15:26:28 (32.3 MB/s) - ‘northanger_abbey.txt’ saved [468091/468091]
#
# --2025-11-03 15:26:28--  https://raw.githubusercontent.com/jonathanblaney/RSE-dropins-2025-6/refs/heads/main/week3-cli/pride_and_prejudice.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 772424 (754K) [text/plain]
# Saving to: ‘pride_and_prejudice.txt’
#
# pride_and_prejudice 100%[===================>] 754.32K  --.-KB/s    in 0.02s
#
# 2025-11-03 15:26:28 (38.4 MB/s) - ‘pride_and_prejudice.txt’ saved [772424/772424]
#
# --2025-11-03 15:26:28--  https://raw.githubusercontent.com/jonathanblaney/RSE-dropins-2025-6/refs/heads/main/week3-cli/sense_and_sensibility.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 712887 (696K) [text/plain]
# Saving to: ‘sense_and_sensibility.txt’
#
# sense_and_sensibili 100%[===================>] 696.18K  --.-KB/s    in 0.02s
#
# 2025-11-03 15:26:29 (33.1 MB/s) - ‘sense_and_sensibility.txt’ saved [712887/712887]

# %%
with open('emma.txt', 'r') as f:
    emma = f.read()
with open('pride_and_prejudice.txt', 'r') as f:
    pride = f.read()
with open('sense_and_sensibility.txt', 'r') as f:
    sense = f.read()
with open('mansfield_park.txt', 'r') as f:
    mansfield = f.read()
with open('northanger_abbey.txt', 'r') as f:
    northanger = f.read()
with open('persuasion.txt', 'r') as f:
    persuasion = f.read()

# %%
emma_words = set(emma.split())
pride_words = set(pride.split())
sense_words = set(sense.split())
mansfield_words = set(mansfield.split())
northanger_words = set(northanger.split())
persuasion_words = set(persuasion.split())

# %%
print(len(emma_words))
print(len(pride_words))
print(len(sense_words))
print(len(mansfield_words))
print(len(northanger_words))
print(len(persuasion_words))
# Out:
# 18012
# 14702
# 13801
# 16717
# 11851
# 11457

# %% [markdown]
# With these sets we can now do set arithmetic. We can find out which words appear in all Austen novels, which appear in Sense and Sensibility and Emma but not in Pride and Prejudice...any combination we're interested in.
#
# To find out which words are only in Northanger Abbey, we ask for Northanger Abbey minus all the others.

# %%
northanger_words - persuasion_words - sense_words - mansfield_words - pride_words - persuasion_words
# Out:
# {'canary-bird,',
#  'lantern—do',
#  'pitiless',
#  'stamp.”',
#  'dwell;',
#  'reviewers',
#  'see-saw',
#  'trouble,”',
#  'muslin.”',
#  'riot?”',
#  'tolerated,',
#  'phaetons,',
#  'concerned;',
#  'pitiful.',
#  'ornamental',
#  'idleness;',
#  'smirk,',
#  'refined',
#  'puce-coloured',
#  'Eleanor,”',
#  'china.',
#  '[1]',
#  'jig',
#  'mournfully',
#  'impediment,',
#  'purpose:',
#  'sleeper.',
#  'did—they',
#  'testimony.',
#  'females,',
#  'unfounded,',
#  'fed',
#  'cavity',
#  'York',
#  'haste!',
#  'her—and',
#  'hunter.',
#  'generality;',
#  'remiss,',
#  'melt',
#  'included,',
#  'touching',
#  'parted—on',
#  'contents,',
#  'court;',
#  'quarrels',
#  'tidy',
#  'unfavourably,',
#  'journal!',
#  'image,',
#  'd——',
#  'General”—to',
#  '23',
#  'specimens',
#  'know”—twisting',
#  'suite',
#  'alleged,',
#  'listened—the',
#  'convent.',
#  'room’s',
#  'convent,',
#  '_effect_',
#  'awe,',
#  'Leicestershire,',
#  'entitled,',
#  'eminence',
#  'relator,',
#  'Swiftly',
#  '“Nobody’s,',
#  'steal',
#  'advice.”',
#  'Allen.”',
#  'dismay,',
#  'divining',
#  'demanded—Mr.',
#  'else!—in',
#  'conceive.',
#  'housemaid’s',
#  '“Promised',
#  'seized,',
#  'enclosed—what',
#  'crowd!',
#  'observer;',
#  'antechamber,',
#  'shuddered',
#  'hateful',
#  'rained;',
#  'chest.',
#  'Christchurch',
#  'innocence,',
#  'instruct,’',
#  'Thorpes,',
#  'page;',
#  'wearying',
#  'assemblies;',
#  'verb',
#  'miles;',
#  'forests',
#  'Rhine,',
#  'adventures,',
#  'ascended,',
#  'haughtiness',
#  'Wedding',
#  'assassins',
#  'erect,',
#  '“Henry!”',
#  'had—she',
#  'enchanted',
#  'broken-winded',
#  'supplications',
#  'General’s?',
#  'dirt.”',
#  'yours—but',
#  'simile.—as',
#  'Hereford.',
#  'neatest,',
#  'home)',
#  'miles!',
#  'part—so',
#  'Mysteries',
#  'sleeve;',
#  'attach,',
#  'flowers.”',
#  'else?',
#  'ill-sized',
#  'affronted.',
#  'suddenness,',
#  'signify.”',
#  'fading',
#  'France.”',
#  'sheet,',
#  'Hotel,',
#  'murdering',
#  'Monk;',
#  'half.”',
#  'best-tempered',
#  'trifler',
#  'deduction',
#  'fender—“how',
#  'wedding-gown.',
#  'alter;',
#  'agreed.',
#  'Rumford,',
#  'horse?',
#  'quadrangle',
#  'meadows,',
#  'tinkling',
#  'brighten',
#  'quizzers',
#  'distances—side-screens',
#  'Northanger.',
#  'Latin;',
#  'raved',
#  'mended,',
#  'withstand.',
#  'fitly',
#  'bliss;',
#  'quell',
#  'random,',
#  'mistaken?',
#  'flights',
#  'courage.',
#  'round.”',
#  'argument?”',
#  'withstanding',
#  'shelf,',
#  'noises,',
#  'curricle-drivers',
#  'turban',
#  'cope',
#  'feeble',
#  'rudiments',
#  'civil.”',
#  'Sure,',
#  'blinding',
#  'Vol.',
#  'sisters—I',
#  'Tilney?',
#  'adding—joining',
#  'receive.',
#  'disengage',
#  'disproportionate',
#  'gold.',
#  'rapture,',
#  'cricket,',
#  'Drummond,',
#  'aversion!',
#  'nicest—by',
#  'rekindling',
#  'set.',
#  '_T;_',
#  'liquor',
#  'acute—neither',
#  '‘nicest,’',
#  'stylishness',
#  'pearls',
#  'waits',
#  'lashed',
#  'mischief’s',
#  'discern?',
#  'by—But',
#  '“Remember—twelve',
#  'harshest',
#  'well-read',
#  'distaste,',
#  'be—with',
#  'explanation:',
#  'costliness',
#  'judgment—”',
#  'lock.”',
#  'spot,”',
#  'tea-house,',
#  'incomprehensibly',
#  'talking!',
#  'Eleanor?',
#  'drawers',
#  'architecture',
#  'serenity,',
#  'unbelieving',
#  'rolled',
#  'quietly—without',
#  'call.”',
#  'furniture—the',
#  'hurry—It',
#  'obligation;',
#  'Pushed',
#  'madam.”',
#  'Tetbury,',
#  'celerity',
#  'nimbly',
#  'intent;',
#  'lost—we',
#  'abbey!',
#  'woes.',
#  'succeeded;',
#  'delightful?',
#  'extinction;',
#  'really—are',
#  'turn,”',
#  'blush),',
#  'reappearance',
#  'rattle!',
#  'flirts',
#  'attended;',
#  'forever!',
#  'haunches,',
#  'intently,',
#  'members,',
#  'search;',
#  'Allen?”',
#  'chest,',
#  'chimney.',
#  'Astonishment',
#  'well-wishers',
#  'tormented,”',
#  'Belle',
#  '19',
#  'regard?',
#  'made—and',
#  'Cecilia,',
#  'shoes—appeared',
#  'edifices',
#  'Thorpe!”',
#  'baronet.',
#  'populous',
#  'remorse;',
#  'postpone',
#  'dissenting',
#  'by;',
#  'gentlemen!',
#  'funded',
#  'compassionately;',
#  'uncommon.',
#  'passport',
#  'criminal,',
#  'cleanliness,',
#  'centred',
#  'rest—but',
#  'finery,',
#  'Midland',
#  'Thorpes',
#  'April_',
#  'moves;',
#  'unlimited',
#  'intimacy!',
#  'wish?',
#  'assuming,',
#  'Louisas.',
#  '‘Do',
#  'tea-room,',
#  'tell?”',
#  'hats',
#  'probability;',
#  'seriously!”',
#  'wars',
#  'died—”',
#  'gown?',
#  'still.”',
#  'misunderstanding.',
#  'animosities',
#  'greatcoat;',
#  'vow!',
#  'presentiments',
#  'Already',
#  'supply—the',
#  '_Bath,',
#  'woe.”',
#  'monastic',
#  'funereal',
#  'fashionable-looking,',
#  'consolation;',
#  'retraction',
#  '“dearest',
#  'unpromising',
#  'messenger.',
#  'Thorpe;',
#  'quite;',
#  'reproach.”',
#  'learn.',
#  'reader',
#  'binding.”',
#  'guineas,',
#  'engagement!',
#  'Feelings',
#  'gates;',
#  'Company',
#  'walkers,',
#  'judge—of',
#  'reversed.',
#  'fallen,',
#  'fears—could',
#  '“Why!',
#  'excessively!',
#  'worse!”',
#  'division,',
#  'captives;',
#  '“be',
#  'object—it',
#  'recognition.',
#  'vacation',
#  'fifth,',
#  'disallow',
#  'see—Is',
#  'sink,',
#  'folly!',
#  'lighter.',
#  'injustice;',
#  'music-master',
#  'Sophia',
#  'distracts',
#  'spirits.”',
#  'incapacity',
#  'deal?”',
#  'declared,[1]',
#  'accomplishing',
#  'horridest',
#  'dignifies',
#  'Black',
#  'Richmond.”',
#  'off.)',
#  'you—gentlemen',
#  'glass.',
#  'mislaid',
#  'pretty—and',
#  'resenting,',
#  'sudden,',
#  'trial.',
#  'civilly?”',
#  'winner;',
#  'card-room,',
#  'Catherine:',
#  'chaises',
#  'chestnut',
#  'eternity',
#  'schoolfellows;',
#  'General.',
#  'shallow',
#  'sprigged',
#  'journey:',
#  'conclusion;',
#  'receding',
#  'views:',
#  'purpose!—it',
#  'rattle;',
#  'immovable.',
#  'burning,',
#  'surer',
#  'five,',
#  'oaks,',
#  'Grandison!',
#  'originality',
#  'miserly;',
#  'surmises,',
#  'event:',
#  'taste:',
#  'Mamma,',
#  'castle,',
#  'chapters;',
#  'Herefordshire,',
#  'admitting?”',
#  'clock,',
#  'Where?”',
#  'relax',
#  'Allens,',
#  'horse!',
#  'beads',
#  'self-occupied.',
#  'emotion—but',
#  'pints',
#  'affirmative,',
#  'breeding!',
#  'fastener,',
#  'quite—more',
#  'particulars—they',
#  'grammar.”',
#  'hungry,',
#  'murdered',
#  'bowed—but',
#  'wild-fowl,',
#  'witch.',
#  'Taken',
#  '“Signify!',
#  'ancestor',
#  'blush,',
#  'worked?”',
#  'tombstones',
#  'patched-on',
#  'Mitchells,',
#  'Putney,',
#  'poison',
#  '“Isabella,',
#  'Brings',
#  'Allen’s',
#  'laughingly,',
#  'vainly',
#  'transpire',
#  'ray',
#  'sea—and',
#  'archway,',
#  'expensively',
#  'go—eight',
#  'wishes)',
#  'resigned,',
#  'unexplored;',
#  '1818—the',
#  'curse',
#  'pretension,',
#  'travels.',
#  'Afterwards',
#  'considerations.',
#  'flirtations,',
#  'Setting',
#  'cooperate',
#  'mysteriousness,',
#  'spars;',
#  'now—very',
#  'trot;',
#  'affliction!”',
#  'Fletcher',
#  'information—amongst',
#  'greatcoat,',
#  'comforting',
#  'dressing-rooms,',
#  'nice-looking',
#  '1816.',
#  'allows',
#  'hour:',
#  'undeceived',
#  'search.',
#  'Somebody',
#  'hair.’',
#  '“Rest!',
#  'melted',
#  'inspired.',
#  'doubling',
#  'meanwhile—the',
#  'greatly,',
#  'books—or',
#  'accommodation,',
#  '(left',
#  'died?”',
#  'back.”',
#  'self-assured',
#  '“Why?',
#  'it—he',
#  'beautiful!',
#  '‘Oh!',
#  'outriders',
#  'partner—but',
#  'drawing—nothing',
#  'Perceiving',
#  'empty,',
#  'Alice.”',
#  'Tilney',
#  'decried.',
#  'horrid!',
#  'down?”',
#  'appearance:',
#  'hoop',
#  'Circumstances',
#  '“five-and-twenty',
#  'borne;',
#  'Abbey!',
#  'Amazingly',
#  'Tears',
#  'lute,',
#  'fill.',
#  'Fullerton.',
#  'example;',
#  'trespassed',
#  'bestows.',
#  'Hodges',
#  'unravelled.',
#  'Morland;',
#  'brickbat',
#  'dark.”',
#  '_most',
#  'cross;',
#  'tumble',
#  'down!',
#  'beware',
#  '_this_—that',
#  'shirked',
#  'lived.”',
#  'are!”',
#  'treated—though',
#  'early?',
#  'trio',
#  'voluntary;',
#  'guilt?',
#  'town-built;',
#  'passage?”',
#  'Point',
#  'usage.',
#  'Stop,',
#  'torments',
#  'faith!',
#  'happen!',
#  'trunk.',
#  'origin;',
#  'Udolpho?”',
#  'cruelty—was',
#  'cells',
#  'Morland—my',
#  'charge,',
#  'detest:',
#  'however—kind',
#  'irrecoverably',
#  'Dorothy',
#  'expose.',
#  'cricket',
#  'simpering',
#  'fretting',
#  'avoid;',
#  'loudest',
#  'positively,',
#  'aim,',
#  'application.',
#  'afternoon’s',
#  'answering,',
#  'finale',
#  'sedentary,',
#  'ABBEY',
#  'Radcliffe,”',
#  'curiously',
#  'sullying',
#  'scrape.',
#  'sleeplessness',
#  'redder',
#  'Writing',
#  'drown',
#  'challenging',
#  '“Bath,',
#  'non-appearance',
#  'obligations;',
#  'unfurnished,',
#  'size—its',
#  'Richard—and',
#  'novel,',
#  'suffered;',
#  'torrents.',
#  'fair?”',
#  'opening—and,',
#  'singularly',
#  'candle,',
#  'unalloyed,',
#  'irritations.',
#  'sampler',
#  'Ladyship!”',
#  'wedding-clothes.',
#  'civilly.',
#  'faster!”',
#  'training',
#  'clogs',
#  'Tilneys’',
#  'curtsies',
#  'Horrid',
#  'home—only',
#  'waive',
#  'alley,',
#  'panels',
#  'passion.',
#  'backed.',
#  'hummed',
#  'gone?”',
#  'Shirts,',
#  'dressmaker,',
#  'least—and',
#  'frolic,',
#  'Catherine!',
#  'spirit—and',
#  'Freeman',
#  'insupportably',
#  'history!',
#  'Twelfth',
#  'lying-in',
#  'described!',
#  'boys’',
#  'say—but',
#  'records,',
#  'resentment—a',
#  'destroyer,',
#  'anybody!”',
#  'origin—jealousy',
#  'torn,”',
#  'too—by',
#  'five-and-twenty,”',
#  'all-conquering',
#  'pursued,',
#  'ruder',
#  'assignment',
#  'variation;',
#  'complacently;',
#  'road—only',
#  'division?',
#  'fortifying',
#  'tarnished',
#  'abbey.”',
#  'unanswerable.',
#  'kind-hearted,',
#  'pump-yard',
#  'another—_he_',
#  'superior;',
#  'insurgents,',
#  'cradle',
#  'drawers,',
#  'dirty.”',
#  'universe.',
#  'heroine,',
#  '“bear',
#  'gone?',
#  'heroic',
#  'suites',
#  'History',
#  'amity,',
#  'Skinners',
#  'untoward.',
#  'Tilneys',
#  'object!',
#  'mistake—I',
#  'just:',
#  'further;',
#  'raining,',
#  'within.”',
#  'moulding,',
#  'tenor',
#  'violently.',
#  'spoke);',
#  'spirits?”—were',
#  'faced',
#  'acute.',
#  'dolls,',
#  'weaken.',
#  'dogs',
#  'raged,',
#  'time—had',
#  'guileless,',
#  'protégée,',
#  'Tetbury.”',
#  'Disappointed',
#  'side!—as',
#  'flavoured',
#  'consisting',
#  'corresponded',
#  'keeping.”',
#  '“Hot!',
#  'morning,”',
#  'convent',
#  'poverty!',
#  'Oriel,',
#  'dissolution;',
#  'triumphs',
#  'Tilney;',
#  'nourish',
#  'surveyor',
#  'Mitchell',
#  'ready-monied',
#  'darkness.”',
#  'waters',
#  'chamber;',
#  'Walcot',
#  'did—almost',
#  'brain.',
#  'peeped',
#  'Milton,',
#  'journal',
#  'descriptions,',
#  'Wick',
#  'captive.',
#  'visitor;',
#  'lamps,',
#  'far?',
#  'bustle.',
#  'Fullerton,',
#  'to—Dear',
#  'Catherine.”',
#  'idea—just',
#  'sonnets,',
#  'taste—though',
#  'malevolent',
#  'landing-places,',
#  'oneself.',
#  'Fullerton?',
#  'excursion,',
#  'cattle',
#  'Julias',
#  'reverential',
#  'particulars?',
#  'necessitous',
#  'amenable.',
#  'portionless,',
#  'Fullerton.”',
#  '“Curricle-hung,',
#  'explained:',
#  '29',
#  'pelisse',
#  'airing?”',
#  'decipher',
#  'errand!”',
#  'thread,',
#  'different—returned',
#  'rickety',
#  'ascertained;',
#  'gallants.',
#  'papas',
#  'tippet.',
#  'emigrant,',
#  'Thorpe?',
#  '“depend',
#  'anyone’s',
#  'that—',
#  'epithets',
#  'gig;',
#  'doing?”',
#  'understood?',
#  'composition,',
#  'ADVERTISEMENT',
#  'exploring',
#  'notion.”',
#  'is—no,',
#  'fiend.',
#  'decrying',
#  'nine;',
#  'veil!',
#  'effect.”',
#  'finished;',
#  'character!—for',
#  'tremble.',
#  'abbey',
#  'wring',
#  'peace;',
#  'sufficient—and',
#  'abbey—for',
#  'Spelling',
#  'deserted—the',
#  'odd.',
#  'pressure',
#  'met!',
#  'add—aware',
#  'friend’s?',
#  'indiscriminating',
#  'hyacinth.',
#  'Anthony,',
#  'Holy',
#  'shape:',
#  'inn-yard',
#  'Tuscany',
#  'puzzles',
#  'promise—the',
#  'assumed,',
#  'before—her',
#  'Cheap',
#  'see-saw,',
#  'Bath—much.”',
#  'singly.',
#  'casements—but',
#  'distantly',
#  'rang,',
#  'Miss——?”',
#  'BY',
#  'unintentional',
#  'transmitting',
#  'airs.',
#  'disquisition',
#  'urge;',
#  'subterraneous',
#  'Montoni!',
#  'included.”',
#  'abyss',
#  'I—but',
#  'mayst',
#  'scarce.”',
#  'to-night',
#  'pattened',
#  'ponderous',
#  'dissipating',
#  'Moreover,',
#  'city,',
#  'King;',
#  'smacked',
#  'Thorpe’s',
#  'Thomson,',
#  'showery,',
#  'courage:',
#  'seen?—Had',
#  'church-yard,',
#  'Classic',
#  'negligent—but',
#  'corner.',
#  'aspect;',
#  'declarations,',
#  'people—and',
#  'palate,',
#  'appearance?',
#  'emblem',
#  'gentleman-coachman',
#  '“Riot!',
#  'Castle!”',
#  'rooms.”',
#  'Frederick.”',
#  'attire;',
#  'sallow',
#  '“Catherine,',
#  'scatter-brained',
#  'consent—happy',
#  'tedious.',
#  'requisites,',
#  'yard.”',
#  'Fletcher,',
#  'progress;',
#  'will?',
#  'cautions',
#  'devolve.',
#  'softening',
#  'coffin',
#  'equipped,',
#  'straw',
#  'rose?”',
#  'toilette',
#  '“Woodston',
#  'lot;',
#  'definition',
#  'stuff!',
#  'concealed;',
#  'again—I',
#  'roused,',
#  'rambles,',
#  'particularly.”',
#  'recess',
#  'fever—its',
#  'farrier’s',
#  'bold.',
#  'Skinners.',
#  'retract.',
#  'general.”',
#  'vault',
#  '“often',
#  'imprisonment.',
#  'ceasing,',
#  'difficulties;',
#  'counterpoise',
#  'bow.”',
#  'treated,',
#  'rose-bush.',
#  'waiters,',
#  'attestation.',
#  'guineas.',
#  'tempest,',
#  'booted',
#  'bed-chamber—where',
#  'wrong?—You',
#  'skeleton,',
#  'clearness',
#  'Catherine’s,',
#  'awful,',
#  'her—Isabella',
#  'productions',
#  'famously.”',
#  'sweat',
#  'Rooms,',
#  'those—whoever',
#  'Udolpho',
#  'Magdalen',
#  'chickens,',
#  'butter’s',
#  'corresponding.',
#  'Thorpe?”',
#  'abbeys',
#  'dressing-gown',
#  'avocations',
#  'placid.',
#  'mysterious!',
#  'gravely—“I',
#  'on—something',
#  'frederick!”',
#  'shutters;',
#  'affectionate;',
#  'wick',
#  'madam?”',
#  'lenient',
#  'Cliff,',
#  'awake:',
#  'father—could',
#  'manuscript',
#  'Modesty',
#  'sixty',
#  'hotel,',
#  'resistance.',
#  'candid,',
#  'Bedford;',
#  'duties—shops',
#  'ignorant.',
#  'rocky',
#  'me.—I',
#  'clocks',
#  '“Me?',
#  'greatcoats.',
#  'beg;',
#  'Christians.',
#  'road-books,',
#  'torment.”',
#  '(sighing',
#  'metal.',
#  'lose.',
#  '14',
#  'because—And',
#  'torment,’',
#  'accepted—and',
#  'decent,',
#  'awfulness',
#  'amounting',
#  'Pondering',
#  'dispatch.',
#  'small;',
#  'storehouse',
#  'Goodwill',
#  'usher',
#  'dirt;',
#  'midnight,',
#  'swelled;',
#  '“Catherine',
#  'wheeled',
#  'benefactors',
#  'delightful—and',
#  'counsels,',
#  'afflicted?”',
#  'reference!',
#  'discreeter',
#  'Eleanor—what',
#  'interesting.”',
#  'darkness.',
#  'be—of',
#  'advertised,',
#  'hyacinth.”',
#  'acquaintance—The',
#  'spend;',
#  'castle?”',
#  'cabinet',
#  'drive,”',
#  'uncoquettish',
#  'position,',
#  'thunder',
#  'refreshments',
#  'stable-yards,',
#  'Mitchells',
#  'park.”',
#  'precincts',
#  '14,',
#  'offence?”',
#  'Neatness',
#  'Morland',
#  'race.',
#  'oiled.',
#  'Sarah’s',
#  '“may',
#  'garden.”',
#  'you?—to-morrow',
#  'weakened.',
#  'propensities—her',
#  'spies,',
#  ...}

# %% [markdown]
# Some of these are a bit suprising. How can we do a quick check? Maybe via the command line!

# %%
# !grep "escort" *.txt
# Out:
# emma.txt:so that Emma found, on being escorted and followed into the second
# emma.txt:Miss Bates and Miss Fairfax, escorted by the two gentlemen, walked into
# mansfield_park.txt:sister in an article of such importance; but he escorted her, with the
# mansfield_park.txt:soon made good. While she was gone Mr. Rushworth arrived, escorting his
# northanger_abbey.txt:to escort them.
# persuasion.txt:her. Lady Dalrymple and Miss Carteret, escorted by Mr Elliot and

# %%
# !grep -w "escort" *.txt
# Out:
# northanger_abbey.txt:to escort them.

# %% [markdown]
# Quite a lot of DH is just counting stuff (and being analytical about what exactly we're counting, what those counts mean, what the limitations of counting are...). You don't need to know loads of Python to do it.

# %% [markdown]
# If we want a unique list of something but keeping the original order, how can we do it. Here's what might politely be called a naive implementation. Because we want the order we stick with lists as our data structures.
#
#
# split the novel into two

# %% [markdown]
# First create two empty lists.

# %%
first_occurrence = []
duplicates = []

# %% [markdown]
# We still have all of Persuasion in memory, but we don't have all the words in it as a list. Let's get that.

# %%
persuasion_all[124:300]
# Out:
# ['EBOOK',
#  'PERSUASION',
#  '***',
#  'Persuasion',
#  'by',
#  'Jane',
#  'Austen',
#  '(1818)',
#  'Contents',
#  'CHAPTER',
#  'I.',
#  'CHAPTER',
#  'II.',
#  'CHAPTER',
#  'III.',
#  'CHAPTER',
#  'IV.',
#  'CHAPTER',
#  'V.',
#  'CHAPTER',
#  'VI.',
#  'CHAPTER',
#  'VII.',
#  'CHAPTER',
#  'VIII.',
#  'CHAPTER',
#  'IX.',
#  'CHAPTER',
#  'X.',
#  'CHAPTER',
#  'XI.',
#  'CHAPTER',
#  'XII.',
#  'CHAPTER',
#  'XIII.',
#  'CHAPTER',
#  'XIV.',
#  'CHAPTER',
#  'XV.',
#  'CHAPTER',
#  'XVI.',
#  'CHAPTER',
#  'XVII.',
#  'CHAPTER',
#  'XVIII.',
#  'CHAPTER',
#  'XIX.',
#  'CHAPTER',
#  'XX.',
#  'CHAPTER',
#  'XXI.',
#  'CHAPTER',
#  'XXII.',
#  'CHAPTER',
#  'XXIII.',
#  'CHAPTER',
#  'XXIV.',
#  'CHAPTER',
#  'I.',
#  'Sir',
#  'Walter',
#  'Elliot,',
#  'of',
#  'Kellynch',
#  'Hall,',
#  'in',
#  'Somersetshire,',
#  'was',
#  'a',
#  'man',
#  'who,',
#  'for',
#  'his',
#  'own',
#  'amusement,',
#  'never',
#  'took',
#  'up',
#  'any',
#  'book',
#  'but',
#  'the',
#  'Baronetage;',
#  'there',
#  'he',
#  'found',
#  'occupation',
#  'for',
#  'an',
#  'idle',
#  'hour,',
#  'and',
#  'consolation',
#  'in',
#  'a',
#  'distressed',
#  'one;',
#  'there',
#  'his',
#  'faculties',
#  'were',
#  'roused',
#  'into',
#  'admiration',
#  'and',
#  'respect,',
#  'by',
#  'contemplating',
#  'the',
#  'limited',
#  'remnant',
#  'of',
#  'the',
#  'earliest',
#  'patents;',
#  'there',
#  'any',
#  'unwelcome',
#  'sensations,',
#  'arising',
#  'from',
#  'domestic',
#  'affairs',
#  'changed',
#  'naturally',
#  'into',
#  'pity',
#  'and',
#  'contempt',
#  'as',
#  'he',
#  'turned',
#  'over',
#  'the',
#  'almost',
#  'endless',
#  'creations',
#  'of',
#  'the',
#  'last',
#  'century;',
#  'and',
#  'there,',
#  'if',
#  'every',
#  'other',
#  'leaf',
#  'were',
#  'powerless,',
#  'he',
#  'could',
#  'read',
#  'his',
#  'own',
#  'history',
#  'with',
#  'an',
#  'interest',
#  'which',
#  'never',
#  'failed.',
#  'This',
#  'was',
#  'the',
#  'page',
#  'at',
#  'which',
#  'the',
#  'favourite',
#  'volume',
#  'always',
#  'opened:',
#  '“ELLIOT',
#  'OF',
#  'KELLYNCH',
#  'HALL.']

# %%
persuasion_all = persuasion.split()

# %% [markdown]
# Python has a built-in `in` operator, which checks if an item is in a list. So we can loop through all the words in Persuasion, check if they're already in `first_occurrence` and add them if not. We don't really need the duplicates list but let's use it for testing the results.

# %% [markdown]
# Lists are slow, especially with loops.

# %%
for word in persuasion_all:
    if word in first_occurrence:
        duplicates.append(word)
    else:
        first_occurrence.append(word)

# %%
first_occurrence[124:174]
# Out:
# ['Sir',
#  'Walter',
#  'Elliot,',
#  'Kellynch',
#  'Hall,',
#  'Somersetshire,',
#  'was',
#  'a',
#  'man',
#  'who,',
#  'his',
#  'own',
#  'amusement,',
#  'never',
#  'took',
#  'up',
#  'any',
#  'book',
#  'but',
#  'Baronetage;',
#  'there',
#  'he',
#  'found',
#  'occupation',
#  'an',
#  'idle',
#  'hour,',
#  'consolation',
#  'distressed',
#  'one;',
#  'faculties',
#  'were',
#  'roused',
#  'into',
#  'admiration',
#  'respect,',
#  'contemplating',
#  'limited',
#  'remnant',
#  'earliest',
#  'patents;',
#  'unwelcome',
#  'sensations,',
#  'arising',
#  'from',
#  'domestic',
#  'affairs',
#  'changed',
#  'naturally',
#  'pity']

# %% [markdown]
# become slow - doing comparisons between strings
#
# deduplicate strings

# %%
duplicates[40:50]
# Out:
# ['CHAPTER',
#  'CHAPTER',
#  'CHAPTER',
#  'CHAPTER',
#  'CHAPTER',
#  'CHAPTER',
#  'CHAPTER',
#  'CHAPTER',
#  'CHAPTER',
#  'CHAPTER']

# %% [markdown]
# But this is a common task! For common tasks, we can rely on Python to have its own optimised solution. Here it is.

# %% [markdown]
# Quicker because - more efficient memory check

# %%
ordered_unique = list(dict.fromkeys(persuasion_all))

# %%
ordered_unique[124:174]
# Out:
# ['Sir',
#  'Walter',
#  'Elliot,',
#  'Kellynch',
#  'Hall,',
#  'Somersetshire,',
#  'was',
#  'a',
#  'man',
#  'who,',
#  'his',
#  'own',
#  'amusement,',
#  'never',
#  'took',
#  'up',
#  'any',
#  'book',
#  'but',
#  'Baronetage;',
#  'there',
#  'he',
#  'found',
#  'occupation',
#  'an',
#  'idle',
#  'hour,',
#  'consolation',
#  'distressed',
#  'one;',
#  'faculties',
#  'were',
#  'roused',
#  'into',
#  'admiration',
#  'respect,',
#  'contemplating',
#  'limited',
#  'remnant',
#  'earliest',
#  'patents;',
#  'unwelcome',
#  'sensations,',
#  'arising',
#  'from',
#  'domestic',
#  'affairs',
#  'changed',
#  'naturally',
#  'pity']

# %% [markdown]
# #### Tuples
#
# Tuples are like lists in that they are *ordered* but they are unlike lists in that they are *immutable*. Tuples go in round brackets.

# %%
austen_canon = ("Sense and Sensibility", "Pride and Prejudice", "Emma", "Mansfield Park", "Northanger Abbey", "Persuasion")

# %% [markdown]
# As long as we're not changing a tuple, we can treat it like a list, for example with a comprehension.

# %%
for novel in austen_canon:
    print(f"{novel} is part of the Austen canon.")

# %% [markdown]
# But we cannot delete from or add to a tuple. It's fixed. If you try you'll get an error.

# %%
austen_canon.append("Sanditon")

# %% [markdown]
# You may not often want to create your own tuples, but Python will often give you tuples. Tuples are efficient, because their length is known in advance. You can always make a tuple into a list if you want to change it.

# %%
variable_canon = list(austen_canon)

# %%
type(variable_canon)

# %% [markdown]
# #### Dictionaries
#
# Dictionaries are pairs of keys and values separated by colons. The syntax is very similar (but not identical) to JSON. Keys must be unique within a dictionary. Values can be any of the data types above, or other dictionaries. So values can be lists or dictionaries can be nested inside dictionaries.

# %% [markdown]
# In command line week we got the number of words in the Austen novels. How would we store that in Python? The most obvious way is a dictionary. The name of the novel is the key and the number of words is the value:

# %%
novel_counts = {"Mansfield Park": 162666, "Pride and Prejudice": 130414, "Sense and Sensibility": 121891, "Persuasion": 86366, "Northanger Abbey": 80259, "Emma": 160590}

# %%
type(novel_counts)
# Out:
# dict

# %%
print(f"Mansfield Park has {novel_counts['Mansfield Park']} words")
# Out:
# Mansfield Park has 162666 words

# %% [markdown]
# We can iterate over a dictionary but the syntax is slightly more complicated than with a list or tuple comprehension. Conventionally the
# key and the value are given the names `k` and `v`.
#
# k
# v

# %%
for k, v in novel_counts.items():
    print(k, v)
# Out:
# Mansfield Park 162666
# Pride and Prejudice 130414
# Sense and Sensibility 121891
# Persuasion 86366
# Northanger Abbey 80259
# Emma 160590

# %% [markdown]
# Just like with the list comprehension above, we can use logic to filter.

# %%
print("The shorter novels are:\n")
for k, v in novel_counts.items():
    if v < 100_000:
        print(k)
# Out:
# The shorter novels are:
#
# Persuasion
# Northanger Abbey

# %%
print(sorted(novel_counts.items()))
# Out:
# [('Emma', 160590), ('Mansfield Park', 162666), ('Northanger Abbey', 80259), ('Persuasion', 86366), ('Pride and Prejudice', 130414), ('Sense and Sensibility', 121891)]

# %% [markdown]
# Sorting by values is more difficult. The general advice is to think of Python dictionaries primarily in terms of keys, not values. But here is one method.

# %%
{k: v for k, v in sorted(novel_counts.items(), key=lambda item: item[1])}
# Out:
# {'Northanger Abbey': 80259,
#  'Persuasion': 86366,
#  'Sense and Sensibility': 121891,
#  'Pride and Prejudice': 130414,
#  'Emma': 160590,
#  'Mansfield Park': 162666}

# %% [markdown]
# Getting the minimum and maximum is also a bit fiddly, but here is one way to do it.

# %%
print(f"The longest novel is {max(novel_counts, key=novel_counts.get)}.")
print(f"The shortest novel is {min(novel_counts, key=novel_counts.get)}.")
# Out:
# The longest novel is Mansfield Park.
# The shortest novel is Northanger Abbey.

# %% [markdown]
# #### Group work/homework
#
# - use a `for` loop to add the Austen novels with < 12 characters in the title to a new list
# - use fstrings to print the lengths of the unique words in each novels in a nicely formatted way
# - use fstrings to print the word counts of the novels in a nicely formatted way
# - modify the logic of the dictionary comprehension to describe each novel as 'long', 'medium' or 'short'
# - extend the list logic so that you can find all the words in Northanger Abbey which are not in Persuasion, but in the order in which they first occur (don't worry about optimising this!)
